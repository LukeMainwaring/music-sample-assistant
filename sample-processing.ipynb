# %%
# Initialize
import librosa
import soundfile as sf
import numpy as np

# %%
# Basic example

# 1. Get the file path to an included audio example
disco_strings_file = 'test_samples/SC_DS_120_strings_stabs_swinging_upward_sting_Gmin.wav'
kshmr_guitar_file = 'test_samples/KSHMR_Latin_GTR_Guitar_90_Am.wav'

sample_rate = 44100 # TODO: determine best sample rate. 44.1 kHz looks most common

# TODO: figure out how to get things like pitch_shift to work with stereo,
# don't want to do all this processing in mono, unless it doesnt make a difference...
mono = True

# 2. Load the audio as a waveform `y`
#    Store the sampling rate as `sr`
current_sample, sample_rate = librosa.load(kshmr_guitar_file, sr=sample_rate, mono=mono)

# %% [markdown]
# ### Grab BPM of sample
# This process only applies to sample loops and not one-shots, since one-shots (typically) do not have a BPM. We are assuming the sample loop filename contains the BPM. The initial idea is to create a regex parser that just looks for any number between 50-200.
#
# This range is arbitrary, but it cannot be too low since many sample filenames contain a low number identifier. It cannot be too high since it could contain an instrument like 808. For example, in the sample, TL_Loops_Drums_Disco_Fill_03_108, we want to get the 108 BPM and ignore 03.

# %%
from sample_parser import parse_sample_bpm

# Basic example
disco_fill_sample = 'TL_Loops_Drums_Disco_Fill_03_108.wav'
sample_bpm = parse_sample_bpm(disco_fill_sample)
sample_bpm
# Out:
# 108

# %%
'''
List of problematic sample filenames for BPM:
- FSW_song_starter_route69_c_minor_99.wav
- FSW_loop_melody_synth_oldlead_route69_99_c_minor.wav
- FSW_loop_bass_synth_ayayobass_route69_99_c_minor.wav
- 125bpm_vocal_98_fx.wav
- EVIGAN_drum_loop_80s_but_new_119.wav
- TA_MK3_FILL_ONESHOT_80_S_125.wav
- 
'''

# Problematic examples
song_starter_sample = 'EVIGAN_drum_loop_80s_but_new_119.wav'
sample_bpm = parse_sample_bpm(song_starter_sample)
sample_bpm

# %% [markdown]
# ### Grab key of sample
# This process applies to both sample loops and one-shots. We are assuming the sample filename contains the key. Most drums, risers, and other FX samples do not have a key in the filename, so we only grab for those that have them included.
#
# The initial idea is to create a regex parser that looks for the key identifier. In Splice, it appears that all key identifiers are at least preceded by an underscore. This could be tricky, since I have seen a wide variety of formats. For example, E minor could look like any of these - Em, Emin, Eminor, E_m, E_min, E_minor, etc. Plus the variations having a sharp or flat in the name. This solution works for now but important to update if I find one more elegant and flexible.

# %%
# Basic example
from sample_parser import parse_sample_key

parse_sample_key(disco_strings_file)
# Out:
# <music21.key.Key of g minor>

# %% [markdown]
# ### Grab all files in Splice directory
# More description later. Mostly for testing

# %%
SPLICE_SAMPLES_PATH = '/Users/lukemainwaring/Splice/sounds/packs'

# %%
import glob
import os

# Easier to read without list comprehension
# splice_files = []
# splice_sample_files = glob.glob(SPLICE_SAMPLES_PATH + '/**/*.wav', recursive=True)
# for sample_file in splice_sample_files:
#     full_file_split = sample_file.split('/')
#     splice_files.append(full_file_split[-1])

splice_files = [sample_file.split('/')[-1] for sample_file in glob.glob(SPLICE_SAMPLES_PATH + '/**/*.wav', recursive=True)]
splice_files
# Out:
# ['SPINNIN_synth_one_shot_high_brass_Bmaj.wav',
#  'SPINNIN_synth_one_shot_classic_stab_Emaj.wav',
#  'SPINNIN_synth_one_shot_short_piano_Fmin.wav',
#  'SPINNIN_synth_one_shot_brass_hit_Emaj.wav',
#  'SPINNIN_melody_loop_falling_bassline_126_Emin.wav',
#  'SPINNIN_melody_loop_dirty_wubs_126_Fmin.wav',
#  'SPINNIN_melody_loop_riddim_cowbell_lead_126_Fmin.wav',
#  'SPINNIN_melody_loop_clubby_bassline_126_Fmin.wav',
#  'SPINNIN_melody_loop_uk_bass_126_Emin.wav',
#  'SPINNIN_melody_loop_warehouse_wobble_stab_125_Fmin.wav',
#  'SPINNIN_melody_loop_intro_wubs_126_Cmaj.wav',
#  'SPINNIN_melody_loop_cruisin_bass_128_Emin.wav',
#  'SPINNIN_melody_loop_dirty_bass_126_Fmin.wav',
#  'SPINNIN_melody_loop_fat_and_bouncy_126_Fmin.wav',
#  'SPINNIN_drum_top_loop_dance_126.wav',
#  'SPINNIN_clap_one_shot_thick.wav',
#  'SPINNIN_kick_one_shot_punch.wav',
#  'SPINNIN_drum_loop_deep_full_loop_126.wav',
#  'SPINNIN_drum_fill_loop_gunshot_126.wav',
#  'SPINNIN_vocal_one_shot_oooh.wav',
#  'SPINNIN_uplifter_one_shot_cool.wav',
#  'SC_RH_152_horns_chords_skanks_classic_Cmaj.wav',
#  'CVS_beat_loop_01_124.wav',
#  'CVS_beat_loop_03_124.wav',
#  'CVS_percussion_loop_07_124.wav',
#  'CVS_tom_loop_04_124.wav',
#  'CVS_synth_one_shot_11_F#.wav',
#  'CVS_synth_one_shot_09_F#.wav',
#  'CVS_synth_one_shot_18_B.wav',
#  'CVS_synth_one_shot_01_G.wav',
#  'CVS_bass_one_shot_14_F.wav',
#  'CVS_bass_one_shot_20_F.wav',
#  'CVS_fx_riser_one_shot_09.wav',
#  'CVS_fx_riser_one_shot_12.wav',
#  'CVS_vocal_one_shot_08.wav',
#  'CVS_clap_one_shot_06.wav',
#  'CVS_snare_one_shot_01.wav',
#  'CVS_tom_conga_one_shot_04.wav',
#  'CVS_808_one_shot_04_C.wav',
#  'KSHMR_Indian_Violin__128__F#m_.wav',
#  'KSHMR_Cinematic_Drums_100BPM_02.wav',
#  'KSHMR_Natural_Ambiance_05_-_Rain.wav',
#  'KSHMR_Choir_02_-_C_Major_High.wav',
#  'KSHMR_Choir_06_-_F#_Major.wav',
#  'KSHMR_Choir_03_-_C_Major_Low.wav',
#  'KSHMR_Choir_05_-_F_Minor.wav',
#  'KSHMR_Choir_04_-_C#_Major.wav',
#  'MAT_ZO_hihat_closed_06.wav',
#  'MAT_ZO_kick_109.wav',
#  'MAT_ZO_snare_094.wav',
#  'MAT_ZO_drum_loop_11_124.wav',
#  'TFH_Cowbell_01_124.wav',
#  'TFH_Reverse_Crash_FX_01_X.wav',
#  'TFH_Synth_Hit_FX_124.wav',
#  'TFH_Crash_FX_03_124.wav',
#  'TFH_Mid_Snare_Fill_03.wav',
#  'TFH_Mid_Snare_Fill_06.wav',
#  'TFH_Long_Snare_Fill_03.wav',
#  'TFH_Drum_Fill_01.wav',
#  'TFH_Short_Snare_Fill_02.wav',
#  'TFH_Top_Loop_10_124.wav',
#  'TFH_Music_Housefilter_124_Em.wav',
#  'TFH_Music_Classic_Synth_Hit_01_124_Am.wav',
#  'TFH_Music_Classic_Synth_03_124_Fm.wav',
#  'TFH_Vocal_Loop_08_124_Am.wav',
#  'TFH_Vocal_Loop_15_124_X.wav',
#  'TFH_Vocal_Loop_12_124_Am.wav',
#  'TFH_Bass_Loop_16_124_Dm.wav',
#  'TFH_Bass_Loop_08_124_Cm.wav',
#  'TFH_Hat_Loop_16_124.wav',
#  'TFH_Hat_Loop_18_124.wav',
#  'hn_hat_hausopen.wav',
#  'hn_fx_bombah.wav',
#  'hn_fx_layzer.wav',
#  'hn_mus125_filta1_Em.wav',
#  'hn_mus125_straw1_A#m.wav',
#  'hn_mus125_stride3_Gm.wav',
#  'hn_mus125_smoothi3_G#m.wav',
#  'SONNY_D_808_18_C.wav',
#  'SONNY_D_hihat_open_11.wav',
#  'SONNY_D_percussion_05.wav',
#  'SONNY_D_kick_09.wav',
#  'SONNY_D_snare_10.wav',
#  'SONNY_D_snare_04.wav',
#  'SONNY_D_snare_14.wav',
#  'SONNY_D_vocal_02.wav',
#  'KSHMR_Song_Starter_Hip_Hop_Mustard_90_Am.wav',
#  'KSHMR_Song_Starter_Hip_Hop_Holy_Water_104_Dm.wav',
#  'KSHMR_Song_Starter_09_Breathing_Texture_140_Dm-F-Em-D#.wav',
#  'KSHMR3_Tom_Fill_11_110_Cinematic.wav',
#  'KSHMR_Cymbal_Transition_24_Reverse_03.wav',
#  'KSHMR_Big_Kick_12_E.wav',
#  'KSHMR_Jungle_Kick_02.wav',
#  'KSHMR_Bass_Stab_10_F.wav',
#  'KSHMR_Bass_Stab_01_E.wav',
#  'KSHMR_Bass_Shot_07_G.wav',
#  'KSHMR_Bass_Shot_04_A.wav',
#  'KSHMR_Synth_Shot_08_C.wav',
#  'KSHMR_Choir_05_Opera_Stab_Em.wav',
#  'KSHMR_Vocal_Melody_38_140_Em.wav',
#  'KSHMR_Indian_Freestyle_Vocal_08_D#m.wav',
#  'KSHMR_Breathing_07_Short_Breath.wav',
#  'KSHMR_Latin_GTR_Guitar_90_Am.wav',
#  'KSHMR_Bird_Call_05_Down_C#.wav',
#  'KSHMR_Sub_Drop_12_G.wav',
#  'KSHMR_Reverse_Vocal_02_Am.wav',
#  'KSHMR_Reverse_Vocal_12_F.wav',
#  'KSHMR_Impact_with_Sweep_03.wav',
#  'KSHMR_Stab_19_G#.wav',
#  'fg_melodic_one_shot_funkbass_Gmin.wav',
#  'fg_kit_futurefunk_bellshine_110_F#maj.wav',
#  'fg_kit_grooveshop_full_110_Fmin.wav',
#  'OLIVER_fx_breath.wav',
#  'OLIVER_fx_stab_hit_D.wav',
#  'OLIVER_fx_m1_dry_ice_add_delay.wav',
#  'OLIVER_fx_reverb_breath.wav',
#  'OLIVER_noise_fx_vinyl_crackle_01.wav',
#  'OLIVER_linn_lm1_one_shot_cowbell_02.wav',
#  'OLIVER_linn_lm1_one_shot_cowbell_01.wav',
#  'OLIVER_clap_one_shot_operator_01.wav',
#  'OLIVER_one_shot_snare_retro_06.wav',
#  'OLIVER_one_shot_snare_punchy_10.wav',
#  'OLIVER_one_shot_snare_disco_02.wav',
#  'OLIVER_percussion_one_shot_cowbell_C.wav',
#  'OLIVER_disco_drum_loop_115.wav',
#  'OLIVER_retro_drum_loop_1984_funk_120.wav',
#  'OLIVER_hihat_drum_loop_live_115.wav',
#  'OLIVER_fill_drum_loop_100_02.wav',
#  'OLIVER_percussion_loop_crowd_party_110.wav',
#  'OLIVER_percussion_loop_disco_cow_120.wav',
#  'OLIVER_percussion_loop_snap_&_breath_90.wav',
#  'OLIVER_kick_snare_combo_drum_loop_hard_future_103.wav',
#  'OLIVER_bass_loop_arpeggio_98_C.wav',
#  'OLIVER_one_shot_bass_C0_04_C.wav',
#  'OLIVER_live_bass_one_shot_hammer_02_F#.wav',
#  'OLIVER_live_bass_one_shot_slide_02_G#.wav',
#  'SPINNIN_bass_synth_loop_wobble_mayhem_126_A#maj.wav',
#  'SPINNIN_atmosphere_loop_church_126_Fmin.wav',
#  'SPINNIN_synth_one_shot_intergalactic_bass_stab_Fmaj.wav',
#  'SPINNIN_top_loop_rocket_fuel_125.wav',
#  'SPINNIN_top_loop_apollo_126.wav',
#  'SPINNIN_clap_one_shot_dirty.wav',
#  'SPINNIN_drum_loop_punchy_kick_126.wav',
#  'SPINNIN_drum_fill_loop_long_builead_one_shot_128.wav',
#  'SPINNIN_drum_fill_loop_losing_time_126_E.wav',
#  'SPINNIN_drum_fill_loop_falling_snare_126.wav',
#  'SPINNIN_drum_fill_loop_clean_126.wav',
#  'SPINNIN_drum_fill_loop_liftoff_126_C.wav',
#  'SPINNIN_impact_one_shot_epic_horns_Emaj.wav',
#  'SPINNIN_downlifter_one_shot_short_and_clean_126.wav',
#  'NICKY_ROMERO_closed_hihat_one_shot_snow.wav',
#  'KARRA_vocal_hook_wet_heartbeat_mix_150_Bbm.wav',
#  'KARRA_vocal_hook_wet_over_you_113_C#m.wav',
#  'KARRA_vocal_hook_dry_over_you_113_C#m.wav',
#  'KARRA_vocal_hook_dry_move_my_body_lead_113_Bm.wav',
#  'KARRA_vocal_reverse_09_150_Bbm.wav',
#  'TL_OneShot_Disco_Side_Stick_05.wav',
#  'TL_OneShot_Disco_Snare_Soft.wav',
#  'TL_OneShot_Disco_Hat_Open_Close_Short.wav',
#  'TL_OneShot_Disco_Hat_Closed_02.wav',
#  'TL_OneShot_Disco_Hat_Closed_01.wav',
#  'TL_OneShot_Disco_Hat_Open_01.wav',
#  'TL_Loops_Drums_Disco_Fill_03_108.wav',
#  'TL_Loops_Drums_Disco_Ghost_Snare_03_118.wav',
#  '90bpm_vocal_11_fx.wav',
#  '125bpm_vocal_98_fx.wav',
#  '123BPM_FX26_MUSIC.wav',
#  'TNYSN_melody_loop_africanchoir_65_Ebmaj.wav',
#  'OS_125_Drum_Loop_Sicko.wav',
#  'OS_169_C#m_Chop_Ennio_1.wav',
#  'SO_SQ_90_strings_boston_full_Fmaj.wav',
#  'SO_SQ_140_strings_pointer_full_pizz_Cmaj.wav',
#  'SO_SQ_80_strings_dalmation_legato_Fmaj.wav',
#  'SO_SQ_80_strings_dalmation_chords_pizz_Fmaj.wav',
#  'BLASTER_stab_one_shot_hucklebuck_Dmaj.wav',
#  'LSL_80_latin_perc_loop_cowbully.wav',
#  '020_Bass_-_One_Shot_E_-_AMPED_Zenhiser.wav',
#  '015_Synth_Hit_F_-_AMPED_Zenhiser.wav',
#  '022_Synth_Hit_G_-_AMPED_Zenhiser.wav',
#  '014_Synth_Hit_Emin_-_AMPED_Zenhiser.wav',
#  '003_White_Noise_Riser_Down_126bpm_-_AMPED_Zenhiser.wav',
#  '001_White_Noise_Riser_Down_126bpm_-_AMPED_Zenhiser.wav',
#  '015_White_Noise_Riser_-_AMPED_Zenhiser.wav',
#  '07_Clap_-_AMPED_Zenhiser.wav',
#  '20_Clap_-_AMPED_Zenhiser.wav',
#  '003_Hi_Hat_-_Closed_-_AMPED_Zenhiser.wav',
#  '030_Shaker_-_AMPED_Zenhiser.wav',
#  '011_Hi_Hat_-_Open_-_AMPED_Zenhiser.wav',
#  '018_Kick_-_AMPED_Zenhiser.wav',
#  '016_Kick_-_AMPED_Zenhiser.wav',
#  '002a_Synth_Loop_126bpm_Gmin_-_AMPED_Zenhiser.wav',
#  '006_a__Synth_Loop_126bpm_D#maj_-_AMPED_Zenhiser.wav',
#  '003_a_Synth_Loop_126bpm_Bmin_-_AMPED_Zenhiser.wav',
#  '011_a__Synth_Loop_126bpm_E_-_AMPED_Zenhiser.wav',
#  '005_d__Drum_Beat_126bpm_-_AMPED_Zenhiser.wav',
#  '015_b__Drum_Beat_126bpm_-_AMPED_Zenhiser.wav',
#  '005_a__Drum_Beat_126bpm_-_AMPED_Zenhiser.wav',
#  '017_Bassline_126bpm_F#_-_AMPED_Zenhiser.wav',
#  '020_Bassline_126bpm_E_-_AMPED_Zenhiser.wav',
#  '010_Vocal_126bpm_D#min_-_AMPED_Zenhiser.wav',
#  '009_Vocal_126bpm_Emin_-_AMPED_Zenhiser.wav',
#  '008_Vocal_126bpm_F_-_AMPED_Zenhiser.wav',
#  'UST_KIT1_90_drums_full_beat_vintage_groove.wav',
#  'UST_KIT1_90_guitar_soul_chords_arp_Emin.wav',
#  'UST_85_guitar_jazzy_chords_Bmin.wav',
#  'UST_94_bass_dirt_funky_slap_finger_Cmin.wav',
#  'UST_90_keys_electric_piano_funk_classic_style_1_Fmin.wav',
#  'LF_percussion_loop_shaker_03_95_v2.wav',
#  'tp_htb_80_drum_loop_full_fat.wav',
#  'SPINNIN_bass_kick_loop_hot_01_124_Gmin.wav',
#  'SPINNIN_percussion_one_shot_raw_02.wav',
#  'SPINNIN_kick_one_shot_dope_01.wav',
#  'SPINNIN_snare_loop_hot_04_124.wav',
#  'SPINNIN_top_percussion_loop_kraft_05__122.wav',
#  'SPINNIN_top_percussion_loop_dope_04_125.wav',
#  'SPINNIN_fx_one_shot_raw_01_Am.wav',
#  'SPINNIN_fx_one_shot_hot_03.wav',
#  'SPINNIN_fx_one_shot_gruv_02.wav',
#  '04_RA_Drum_Loop_124_Full.wav',
#  'Kit4_RA_Paino1_Am_124.wav',
#  'Kit2_RA_Synth1_Dm_124.wav',
#  'Kit3_RA_Synth1_Dm_124.wav',
#  'TA_UHT_HAT_ONESHOT_OPEN.wav',
#  'TA_UHT_FX_LOOP_DISCO_124_Gm.wav',
#  'TA_UHT_DRUMS_LOOP_TREAD_PERC_LOOP_124.wav',
#  'TA_UHT_BASS_LOOP_BUNCE_126_C.wav',
#  'TA_UHT_BASS_LOOP_FLOW_124_Gm.wav',
#  'BOI1DA_kick_14.wav',
#  'SPINNIN_POP_DANCE_fx_riser_six_C.wav',
#  'SPINNIN_POP_DANCE_synth_jpad_C.wav',
#  'SPINNIN_POP_DANCE_synth_one_shot_organ_G#.wav',
#  'SPINNIN_POP_DANCE_synth_90s_orbass_C.wav',
#  'SPINNIN_POP_DANCE_120_bass_loop_piano_house_Bmin.wav',
#  'SPINNIN_POP_DANCE_122_bass_loop_organ_A#min.wav',
#  'SPINNIN_POP_DANCE_100_bass_loop_fever_G#min.wav',
#  'SPINNIN_POP_DANCE_95_bass_loop_simple_C#maj.wav',
#  'SPINNIN_POP_DANCE_107_melody_loop_summer_Cmaj.wav',
#  'SPINNIN_POP_DANCE_125_guitar_loop_western_dry_Amin.wav',
#  'SPINNIN_POP_DANCE_122_chord_loop_analog_dreams_Dmin.wav',
#  'SPINNIN_POP_DANCE_107_chord_loop_summer_Cmaj.wav',
#  'SPINNIN_POP_DANCE_percussion_hollow_tom.wav',
#  'SPINNIN_POP_DANCE_kick_trap.wav',
#  'SPINNIN_POP_DANCE_124_drum_kit_loop_dance_clap.wav',
#  'SPINNIN_POP_DANCE_116_top_loop_sunshine.wav',
#  'SPINNIN_POP_DANCE_120_top_loop_groovy.wav',
#  'SPINNIN_POP_DANCE_135_buildup_short.wav',
#  'SOUNDDOCTRINE_therevival_one_shot_organ_chord_drive_Fsus4.wav',
#  'SOUNDDOCTRINE_therevival_one_shot_organ_chord_Amaj.wav',
#  'SOUNDDOCTRINE_therevival_one_shot_organ_chord_Gmin.wav',
#  'SOUNDDOCTRINE_therevival_melodic_loop_15_vocals_soprano_ohs_ahs_gospel_soul_67.5_bpm_Cmin.wav',
#  'SOUNDDOCTRINE_therevival_melodic_loop_02_female_vocal_alto_gospel_60_bpm_F#maj.wav',
#  'SOUNDDOCTRINE_therevival_melodic_loop_03_female_vocal_alto_gospel_soul_70_bpm_Ebmaj.wav',
#  'SO_WP_110_perc_loop_bboy_dark.wav',
#  'FX_03-24b.wav',
#  'FX_06-24b_2.wav',
#  'FX_06-24b_1.wav',
#  'FX_06.wav',
#  'FX_03.wav',
#  'FX_06-24b.wav',
#  'TH_Kick_18_E-24b.wav',
#  'TH_Kick_18_E.wav',
#  'TH_Drum_Loop_07_Top_124-24b.wav',
#  'TH_Drum_Loop_07_Top_124-24b_2.wav',
#  'TH_Drum_Loop_07_Top_124-24b_1.wav',
#  'TH_Drum_Loop_07_Top_124.wav',
#  'TH_Kit3_Riser_124_D#m.wav',
#  'TH_Kit3_Riser_124_D#m-24b.wav',
#  'TH_Kit3_Vocal_124_D#m.wav',
#  'TH_Kit3_Synth_Lead_2_DRY_124_D#m.wav',
#  'TH_Kit3_Snare_Roll_124.wav',
#  'TH_Kit3_FX_4.wav',
#  'TH_Kit3_Synth_Lead_2_WET_124_D#m.wav',
#  'TH_Kit3_Riser_124_D#m-24b_1.wav',
#  'TH_Kit3_Riser_124_D#m-24b_2.wav',
#  'TH_Kit3_Snare_Roll_124-24b.wav',
#  'TH_Kit3_Riser_124_D#m-24b_3.wav',
#  'TH_Kit6_Bass_Loop_WET_125_F#m.wav',
#  'TH_Kit6_Synth_Lead_1_WET_125_F#m.wav',
#  'TH_Kit6_Synth_Lead_1_WET_125_F#m-24b.wav',
#  'TH_Kit5_FX_3.wav',
#  'TH_Kit2_Kick_2.wav',
#  'TH_Kit2_Kick_2-24b_1.wav',
#  'TH_Kit2_Kick_2-24b.wav',
#  'TH_Kit4_Vocal_125_G#m.wav',
#  'TH_Kit4_Vocal_125_G#m-24b.wav',
#  'BRS_Thunder_Clap_Med_No_Rain_1.wav',
#  'KURA_128_synth_loop_mather_Fmin.wav',
#  'KURA_horn_long_E.wav',
#  'KURA_128_transition_808_snare.wav',
#  'KURA_kick_house_G#.wav',
#  'PL_VHA_Kit_05_Gospel_124_G#_Tail.wav',
#  'WTB_TRAPSUB_A_04.wav',
#  'EX_US_Foley_Bat_Call_Brown_Dry.wav',
#  'PFUNK_102_trazae_synth_bass_loop_mial_moog_Ebmin.wav',
#  'PFUNK_120_scottie_clinton_vocal_loop_fart_in_my_ear_Emin.wav',
#  'PFUNK_120_scottie_clinton_vocal_loop_colors_out_your_mind_03_Emin.wav',
#  'PFUNK_120_scottie_clinton_vocal_loop_take_you_Abmin.wav',
#  'PFUNK_110_patavian_lewis_vocal_loop_lets_boogie_B_chromatic.wav',
#  'PFUNK_100_patavian_lewis_vocal_phrase_funk_you_want_Eb.wav',
#  'PFUNK_111_george_clinton_bass_drum_loop_where_is_the_party_Emin.wav',
#  'PFUNK_100_danny_bedrosian_clav_loop_Emin.wav',
#  'BPM120_Ab_Synth_11.wav',
#  'QUIX_vocal_ahh.wav',
#  'FHR_kit5_Drop_Clap_Support_one_shot.wav',
#  'FHR_kit2_Break_Fill_Long_128.wav',
#  'FHR_kit3_Drop_Drum_Loop_124.wav',
#  'FHR_kit3_Break_Low_Saw_124_A_minor.wav',
#  'FHR_kit3_Break_Tremolo_Strings_Fill_124_A_minor.wav',
#  'FHR_kit3_Break_Piano_Reverse_FX_124_A_minor.wav',
#  'dfg2_gtr115_uhaul1_Am.wav',
#  'dfg2_gtr125_autowah1_Am9.wav',
#  'dfg2_gtr125_mutedriff_Am.wav',
#  'EOAV1_03_Backing_F#_Dry_122.wav',
#  'SPARKEE_bass_loop_funky3_110_Em.wav',
#  'SPARKEE_bass_loop_funky5_110_Gm.wav',
#  'SPARKEE_bass_loop_funky10_110_Am.wav',
#  'SPARKEE_guitar_loop_stanky_Em_110bpm.wav',
#  'SPARKEE_bass_one_shot_long_note_C.wav',
#  'SPARKEE_Angelic_Chords_F#m_116bpm.wav',
#  'SPARKEE_Funky_Chord_Loop_Am_114bpm_02.wav',
#  'SPARKEE_Tropical_Summer_Chord_Loop_Am_117bpm.wav',
#  'MURDA_KICK_SOUTHERN.wav',
#  '80_Bpm_-_Funk_n_Soul_Band_Horns_A#.wav',
#  'SO_SS_140_vocal_riff_flylullaby_pitched_F.wav',
#  'SO_SS_90_vocal_harmony_hah_downer_delay_Am.wav',
#  'SO_SS_120_vocal_harmony_hmm_pad_chill_G.wav',
#  'BRLY_ALVE_reverse_breathe.wav',
#  'BRLY_ALVE_reverse_majorbrass_Cmaj.wav',
#  'BRLY_ALVE_bass_coin_02_Gb.wav',
#  'BRLY_ALVE_bass_clank_Eb.wav',
#  'BRLY_ALVE_pad_reactor_F.wav',
#  'BRLY_ALIVE_150_synth_loop_arpagon_Fmin.wav',
#  'BRLY_ALVE_tom_linnthree.wav',
#  'BRLY_ALVE_kick_shenzhen.wav',
#  'BRLY_ALVE_kick_linn.wav',
#  'BRLY_ALVE_140_drum_loop_hybrid.wav',
#  'YNG_120_drum_loop_trap_bless.wav',
#  'YNG_80_drum_loop_city_complex.wav',
#  'YNG_80_drum_loop_NY_fire.wav',
#  'YNG_130_drum_loop_buyout_no_kick.wav',
#  'YNG_80_drum_loop_NY_fire_no_kick.wav',
#  'YNG_80_hihat_loop_diamonds.wav',
#  'YNG_140_rap_vocal_bandman_pitched.wav',
#  'YNG_120_melodic_chop_loop_jays_exploit_Cm.wav',
#  'YNG_80_melodic_chop_loop_katas_krime_Cm.wav',
#  'YNG_80_melodic_chop_loop_bigapple_blazin_Dm.wav',
#  'YNG_100_melodic_chop_loop_digga_evolve_Fm.wav',
#  'YNG_140_808_sub_knockin_Cm.wav',
#  'YNG_120_melodic_loop_soul_down_70s_hihfi_Gm.wav',
#  'YNG_120_melodic_loop_soul_down_70s_lofi_Gm.wav',
#  'GUY_GERBER_drum_loop_morning_breath_01_120.wav',
#  '02_DMT_Clap.wav',
#  '07_DMT_Drum_Loop_Stripped_2_128.wav',
#  '09_DMT_Drum_Loop_Full_128.wav',
#  'LF_clap_machine.wav',
#  'LF_85_percussion_loop_laidback_shaker.wav',
#  'LF_140_percussion_loop_shaker_crisp.wav',
#  'LF_fx_reverse_02.wav',
#  'LF_90_melodic_loop_future_future_bass_D#min.wav',
#  'lh_oneshot_melodic_whist_F.wav',
#  '007_Shaker_1_-_DUSTY_Zenhiser.wav',
#  '29_Drum_Loop_125.wav',
#  '21_Drum_Loop_125.wav',
#  '05_Snare.wav',
#  'synth_125_F_2.wav',
#  'NOIZU_fx_laser_disco.wav',
#  'NOIZU_125_white_noise_riser_02.wav',
#  'NOIZU_hihat_open_long_03.wav',
#  'NOIZU_hihat_open_long_05.wav',
#  'NOIZU_hihat_open_long_08.wav',
#  'NOIZU_kick_tech_house_deep_03.wav',
#  'NOIZU_kick_tech_house_wood_04.wav',
#  'NOIZU_clap_tech_house_classic_02.wav',
#  'NOIZU_percussion_rim_classic_03.wav',
#  'NOIZU_125_cowbell_loop_classic.wav',
#  'NOIZU_125_cowbell_loop_tight.wav',
#  'NOIZU_125_snare_loop_riser_straight_long_09.wav',
#  'NOIZU_125_snare_loop_riser_straight_short_08.wav',
#  'NOIZU_125_shaker_loop_airy.wav',
#  'NOIZU_synth_drop_hoover_low_F.wav',
#  'NOIZU_125_bass_loop_runner_F.wav',
#  'TA_TTS_TB_FX_ONESHOT_ARTIFACTS_Abm.wav',
#  'TA_TTS_TB_FX_ONESHOT_BIG_Am.wav',
#  'TA_TTS_TB_FX_ONESHOT_WOODY_Gm.wav',
#  'TA_TTS_TB_PERC_LOOP_LOADED_125.wav',
#  'TA_TTS_TB_TOPS_LOOP_CLUNK_125.wav',
#  'TA_TTS_TB_SHAKER_LOOP_DEEP_125.wav',
#  'TA_TTS_TB_KICK_LOOP_DEEP_125.wav',
#  'TA_TTS_TB_OHH_LOOP_TRICKY_125.wav',
#  'TA_TTS_TB_PERC_LOOP_TRICKY_125.wav',
#  'TA_TTS_TB_TOPS_LOOP_DRIFT_125.wav',
#  'TA_TTS_TB_FULL_LOOP_LIVELY_125.wav',
#  'TA_TTS_TB_FULL_LOOP_OG_125.wav',
#  'TA_TTS_TB_KICK_LOOP_BASE_125.wav',
#  'TA_TTS_TB_BASS_LOOP_BASSLINE_08_125_Amin.wav',
#  'TA_TTS_TB_BASS_LOOP_PULSE_X_125_Gb.wav',
#  'TA_TTS_TB_BASS_LOOP_REESE_125_Am.wav',
#  'TA_TTS_TB_SYNTH_LOOP_WARM_C.wav',
#  '007_Hi_Hat_-_ORGANICHOUSE_Zenhiser.wav',
#  '050_Percussion_-_ORGANICHOUSE_Zenhiser.wav',
#  '002_Clap_-_ORGANICHOUSE_Zenhiser.wav',
#  '022__b__Drum_Loop__Without_Kick__120bpm_-_ORGANICHOUSE_Zenhiser.wav',
#  'SO_JS_110_vocal_breathe_dry_Fmin.wav',
#  'SO_JS_110_melodic_loop_question_Dmin.wav',
#  'TA_MK3_CRASH_ONESHOT_CRUSHED.wav',
#  'TA_MK3_RIDE_ONESHOT_HOT.wav',
#  'TA_MK3_HAT_ONESHOT_TIGHT.wav',
#  'TA_MK3_HAT_ONESHOT_LONG.wav',
#  'TA_MK3_PERC_ONESHOT_TICK.wav',
#  'TA_MK3_KICK_ONESHOT_CORN.wav',
#  'TA_MK3_KICK_ONESHOT_CHUNKY.wav',
#  'TA_MK3_EFX_ONESHOT_SHARP.wav',
#  'TA_MK3_FILL_ONESHOT_80_S_125.wav',
#  'TA_MK3_FILL_ONESHOT_TOPPY_124.wav',
#  'TA_MK3_SNAREROLL_ONESHOT_JAZZ_125.wav',
#  'TA_MK3_SNAREROLL_ONESHOT_ROLLER_124.wav',
#  'TA_MK3_SNAREROLL_ONESHOT_HOT_124.wav',
#  'TA_MK3_SNAREROLL_ONESHOT_NRG_125.wav',
#  'TA_MK3_FILL_ONESHOT_PROGRESSIVE_125.wav',
#  'TA_MK3_SNAREROLL_ONESHOT_MIDDLE_125.wav',
#  'TA_MK3_PERC_LOOP_GROOVEJET_125.wav',
#  'TA_MK3_PERC_LOOP_JUNKY_125.wav',
#  'TA_MK3_PERC_LOOP_DEEP_125.wav',
#  'TA_MK3_PERC_LOOP_MOVIN_125.wav',
#  'TA_MK3_PERC_LOOP_TRIBESMAN_125.wav',
#  'TA_MK3_KICK_LOOP_HUSKY_124.wav',
#  'TA_MK3_KICK_LOOP_FULL_125.wav',
#  'TA_MK3_ATMOS_LOOP_GAMER_THEME_124.wav',
#  'TA_MK3_ATMOS_LOOP_PARADISE_125.wav',
#  'TA_MK3_ATMOS_LOOP_ANGELS_124.wav',
#  'TA_MK3_VOX_LOOP_PUMPIN.wav',
#  'TA_MK3_VOX_LOOP_FUNKY_BEAT.wav',
#  'TA_MK3_VOX_LOOP_DEEPER.wav',
#  'TA_MK3_TOPS_DANSE_125.wav',
#  'TA_MK3_TOPS_BIG_125.wav',
#  'TA_MK3_TOPS_WIGGLE_125.wav',
#  'TA_MK3_TOPS_TIMELESS_125.wav',
#  'TA_MK3_MUSIC_LOOP_JUNGLE_RUN_125.wav',
#  'TA_MK3_HAT_LOOP_SHINY_125.wav',
#  'TA_MK3_DRUM_LOOP_SAMBA_PERC_125.wav',
#  'TA_MK3_DRUM_LOOP_COFFEE_KICK_125.wav',
#  'TA_MK3_DRUM_LOOP_TITAN_FULL_125.wav',
#  'TA_MK3_DRUM_LOOP_CHERRY_HAT_125.wav',
#  'TA_MK3_DRUM_LOOP_CHERRY_KICK_125.wav',
#  'Feeling_Funky.wav',
#  '110_-_Dm_-_Flute_Lick.wav',
#  '110_-_Dm_-_Sax_Loop.wav',
#  '120_-_Am_-_The_Time_is_Now.wav',
#  'THE_KOUNT_80_sequenced_drum_loop_bop.wav',
#  'FSW_one_shot_cymbal_02.wav',
#  'FSW_one_shot_hihat_open_sunrise.wav',
#  'FSW_one_shot_hihat_closed_sunrise.wav',
#  'FSW_one_shot_percussion_cowbell_allnight.wav',
#  'FSW_one_shot_percussion_shaker_keeprunning.wav',
#  'FSW_one_shot_percussion_stick_sunrise.wav',
#  'FSW_one_shot_percussion_snap_serpantine.wav',
#  'FSW_one_shot_percussion_cave_sunset.wav',
#  'FSW_one_shot_percussion_tom_sunrise.wav',
#  'FSW_one_shot_percussion_snap_23carrots.wav',
#  'FSW_one_shot_clap_03.wav',
#  'FSW_one_shot_clap_sunrise.wav',
#  'FSW_one_shot_clap_big_serpantine.wav',
#  'FSW_one_shot_clap_serpantine.wav',
#  'FSW_one_shot_clap_big_sunset.wav',
#  'FSW_one_shot_clap_lazyevening.wav',
#  'FSW_one_shot_snare_classic_05.wav',
#  'FSW_one_shot_snare_sunrise.wav',
#  'FSW_one_shot_kick_01_sunrise.wav',
#  'FSW_one_shot_kick_fashion.wav',
#  'FSW_one_shot_kick_classic_01.wav',
#  'FSW_one_shot_kick_classic_02.wav',
#  'FSW_one_shot_kick_02_sunrise.wav',
#  'FSW_one_shot_melodic_synth_juno_c.wav',
#  'FSW_one_shot_melodic_bass_dartfunk_c.wav',
#  'FSW_one_shot_melodic_bass_speakmoog_c.wav',
#  'FSW_one_shot_melodic_bass_bacterium_c.wav',
#  'FSW_one_shot_melodic_bass_gozilla_c.wav',
#  'FSW_loop_chord_brass_bigband_serpantine_116_f_minor.wav',
#  'FSW_loop_chord_keys_piano_keeprunning_110_b_minor.wav',
#  'FSW_loop_chord_keys_cleanrhodes_e_minor_100.wav',
#  'FSW_loop_chord_guitar_funkyamp_sunset_100_d_minor.wav',
#  'FSW_loop_bass_synth_ayayobass_route69_99_c_minor.wav',
#  'FSW_loop_bass_bouncebass_d_minor_110.wav',
#  'FSW_loop_bass_synth_b_minor_115.wav',
#  'FSW_loop_bass_synth_d_minor_120.wav',
#  'FSW_loop_bass_fatsquare_e_minor_100.wav',
#  'FSW_loop_bass_accoustic_ampbass_01_dancewithme_114_d_minor.wav',
#  'FSW_song_starter_route69_c_minor_99.wav',
#  'FSW_song_starter_23carrots_f_minor_107.wav',
#  'FSW_song_starter_dancewithme_d_minor_114.wav',
#  'FSW_song_starter_saygoodbye_d#_minor_80.wav',
#  'FSW_loop_melody_synth_oldlead_route69_99_c_minor.wav',
#  'FSW_loop_melody_synth_dabjunk_f_minor_110.wav',
#  'FSW_loop_melody_strings_violins_allnight_119_f_minor.wav',
#  'FSW_loop_melody_vocals_uglychoir_saygoodbye_d#_minor_80.wav',
#  'FSW_one_shot_fx_sweep.wav',
#  'FSW_one_shot_fx_reverce_sweep_fashion.wav',
#  'FSW_one_shot_fx_vinylnoise_warmorning.wav',
#  'FSW_one_shot_fx_lazer_04.wav',
#  'FSW_one_shot_fx_synth_revercesaw_dancewithme.wav',
#  'FSW_one_shot_fx_sweepfx_sunset.wav',
#  'FSW_one_shot_bass_14_c.wav',
#  'FSW_one_shot_bass_09_c.wav',
#  'FSW_one_shot_bass_10_c.wav',
#  'FSW_one_shot_bass_11_c.wav',
#  'FSW_one_shot_bass_06_c.wav',
#  'FSW_one_shot_bass_02_c.wav',
#  'FSW_one_shot_bass_07_c.wav',
#  'FSW_loop_percussion_bongo_124.wav',
#  'FSW_loop_percussion_snap_23carrots_107.wav',
#  'FSW_loop_percussion_shaker_kaytrafunk_111.wav',
#  'FSW_loop_percussion_shaker_allnight_119.wav',
#  'FSW_loop_percussion_shaker_sunrise_110.wav',
#  'FSW_loop_kick_wrmorning_110.wav',
#  'FSW_loop_full_drums_fashion_115.wav',
#  'FSW_loop_full_drums_warmorning_110.wav',
#  'FSW_loop_full_drums_route69_99.wav',
#  'FSW_loop_full_drums_waveride_108.wav',
#  'FSW_loop_full_drums_dancewithme_114.wav',
#  'FSW_loop_full_drums_keeprunning_110.wav',
#  'FSW_loop_full_drums_sunrise_110.wav',
#  'FSW_loop_full_drums_allnight_119.wav',
#  'FSW_loop_clap_23carrots_107.wav',
#  'FSW_loop_clap_02_allnight_119.wav',
#  'FSW_loop_fill_06_115.wav',
#  'FSW_loop_fill_01_120.wav',
#  'FSW_loop_hihat_waveride_108.wav',
#  'SO_AM_114_zither_aife_Amin.wav',
#  'SO_AM_90_voice_jess_topanga_Gmaj.wav',
#  'SS_SS_vocals_adlib_roll_high.wav',
#  'SS_SS_vocals_kebali_tune_Em.wav',
#  'SS_SS_105_kora_touba_driving_Am.wav',
#  'AC_SLATER_bass_loop_wubby_128_G.wav',
#  'XG_ambience_tunnel_whistle.wav',
#  'SCVNGR_vocal_gasp_whisper_dry.wav',
#  'JKid_Voice_2_F_Min_Oh_Women.wav',
#  'JKid_Voice_2_F_Min_Oh_Women-24b.wav',
#  'JKid_Voice_1_F_Min_Ah_Women-24b.wav',
#  'JKid_Voice_1_F_Min_Ah_Women.wav',
#  'CSR_70_soul_stack_chopped_black_and_yellow_pitched_Fm.wav',
#  'CSR_95_horns_chopped_the_king_is_dead_Gm.wav',
#  'OS_Snare_Bright_Snaps_1.wav',
#  'NT_Dm_122_ForYou_Bridge__Wet_.wav',
#  'GH_FX_Uplifter_03_124.wav',
#  'EX_ATSM_20_Inch_Highwall_Bowl_Roll_B.wav',
#  'EX_ATSM_Singing_Bowl_Low_Hit_D.wav',
#  'FL_JTH_03_Full_Loop_127.wav',
#  'FL_JTH_07_Top_Loop_125.wav',
#  'FL_JTH_03_Top_Loop_127.wav',
#  'FL_JTH_PERC_13.wav',
#  'SH_JTH_13_Vocal_Loop_125.wav',
#  'FL_JTH_05_Synth_Loop_125_G.wav',
#  'FL_JTH_06_SFX_Loop_128.wav',
#  'FL_JTH_05_Bassline_125_G.wav',
#  'FL_JTH_07_Bassline_126_G.wav',
#  'Snare_TakeMeBack.wav',
#  'DrumLoop_BoopBopAhh_110.wav',
#  'GuitarLoop_SunRise_120_Fm7DRY.wav',
#  'OLIVER_hits_fx_one_shot_disco_string_stab_Bmaj.wav',
#  'OLIVER_retro_drum_loop_lofi_machine_kick_snare_85.wav',
#  'OLIVER_retro_drum_loop_perfect_clean_disco_100.wav',
#  'OLIVER_kick_snare_combo_drum_loop_analog_house_120.wav',
#  'OLIVER_modern_drum_loop_zoomer_kick_snare_100.wav',
#  'OLIVER_kick_eighties_drum_one_shot_jimmy.wav',
#  'LENNO_fx_loon_classic.wav',
#  'LENNO_fx_noise_up_01.wav',
#  'LENNO_fx_atmosphere_saeki_C#maj.wav',
#  'LENNO_120_synth_loop_penta_quick_arpeggio_Fmin.wav',
#  'LENNO_122_synth_loop_magical_quick_arpeggio_Fmin.wav',
#  'LENNO_synth_quick_arpeggio_dive_Bmin.wav',
#  'LENNO_synth_bass_juno_F#maj.wav',
#  'LENNO_percussion_cowbell_linn_C.wav',
#  'LENNO_tom_standard_mid.wav',
#  'LENNO_kick_modern_motion.wav',
#  'LENNO_116_drum_fill_onwards.wav',
#  'LENNO_120_drum_fill_disco_inferno.wav',
#  'LENNO_107_drum_loop_top_magic.wav',
#  'LENNO_112_drum_loop_top_groovy_machine.wav',
#  'TFH2_Percussion_Loop_11_124.wav',
#  'TFH2_Kick_Loop_10_124.wav',
#  'TFH2_Drum_Fill_18_124.wav',
#  'TFH2_Clap_Loop_12_124.wav',
#  'TFH2_Uplifting_FX_Loop_06_124.wav',
#  'TFH2_Misc_FX_Loop_06_124.wav',
#  'TFH2_Misc_FX_Loop_03_124.wav',
#  'TFH2_Misc_FX_Loop_01_124.wav',
#  'TFH2_Top_Loop_08_124.wav',
#  'TFH2_Top_Loop_17_124.wav',
#  'TFH2_Brass_Hit_Loop_01_Cm_124.wav',
#  'TFH2_Classic_Synth_Loop_05_G#m_124.wav',
#  'TFH2_Classic_Synth_Loop_04_Bm_124.wav',
#  'TFH2_Disco_Hit_Loop_09_Am_124.wav',
#  'TFH2_Discofilter_Loop_07_F#m_124.wav',
#  'TFH2_Funky_Bass_Loop_10_G#m_124.wav',
#  'TFH2_Vocal_Loop_26_X_124.wav',
#  'TFH2_Vocal_Loop_12_G#m_124.wav',
#  'TFH2_Vocal_Loop_27_X_124.wav',
#  'TFH2_Vocal_Loop_09_Cm_124.wav',
#  'TFH2_Bass_Loop_04_G#m_124.wav',
#  'SS_C_steel_drum_3.wav',
#  'SS_100_Bbm_i_see_thunder_plucks.wav',
#  'fdt_vocal_loop_message_124_C#m.wav',
#  'TA_MK_TOPS20_124bpm_Em.wav',
#  'TA_MK_TOPS1_124bpm_Gbm.wav',
#  'TA_MK_TOPS21_125bpm_Bm.wav',
#  'TA_MK_TOPS14_124bpm_Gm.wav',
#  'TA_MK_KICKS19_124bpm_Am.wav',
#  'TA_MK_DRUMS8_124bpm_Gm.wav',
#  'TA_MK_ATMOS_14_125bpm_E.wav',
#  'TA_MK_SNAREROLL4_124bpm_Bm.wav',
#  'TA_MK_SNAREROLL3_124bpm_Gm.wav',
#  'TA_MK_BASS11_124bpm_Gm.wav',
#  'TA_MK_VOX_FEMALE20_124bpm_Gm.wav',
#  'TA_MK_VOX_FEMALE8_124bpm_Dbm.wav',
#  'TA_MK_VOX_FEMALE12_124bpm_Db.wav',
#  'TA_MK_KICK_17.wav',
#  'TA_MK_KICK_5.wav',
#  'TA_MK_STAB_2_Bbm.wav',
#  'TA_MK_STAB_8_A.wav',
#  'TA_MK_CLAP_13.wav',
#  'TA_MK_CLAP_12.wav',
#  'TA_MK_RISER_17_126bpm_A.wav',
#  'TA_MK_RISER_2_126bpm_Gm.wav',
#  'JPXG_bass_one_shot_hard_808_Ebmin.wav',
#  'JPXG_bass_one_shot_clipped_808_Eb.wav',
#  'JPXG_bass_one_shot_sludge_808_F#min.wav',
#  'JPXG_drum_loop_adhd_kick_01_126.wav',
#  'JPXG_kick_one_shot_clean_punchy.wav',
#  'JPXG_vocal_one_shot_bad_bxtch.wav',
#  'ff_djh_snare_mid_layer.wav',
#  'ff_djh_synth_brokensynth_D.wav',
#  'ff_djh_124_drum_fill_livekit_snare.wav',
#  'ff_djh_126_drum_fill_sixteens_snare.wav',
#  'ff_djh_126_fx_loop_chained.wav',
#  'ff_djh_126_fx_loop_siren_1.wav',
#  'ff_djh_126_fx_loop_warp.wav',
#  'ff_djh_126_kit_loop_flow_vocal_Gmin.wav',
#  'ff_djh_126_atmosphere_loop_growl_Amin.wav',
#  'ff_djh_126_texture_loop_noisepump.wav',
#  'drop__loop__cowbell.wav',
#  'RT_Gospel_Choir_All_Stars_Oh_ya_3_Vocals__one_shot.wav',
#  'RT_Gospel_Choir_All_Stars_YES__3_Vocals__one_shot.wav',
#  'LENNO_clap_real_deal_v2.wav',
#  'LENNO_clap_laser_sweep_v2.wav',
#  'LENNO_tom_disco_02_v2.wav',
#  'LENNO_hihat_faze_v2.wav',
#  'LENNO_hihat_eight_oh_nine_v2.wav',
#  'LENNO_snare_rim_v2.wav',
#  'LENNO_snap_wide_v2.wav',
#  'LENNO_synth_loop_crystal_122_F#min_v2.wav',
#  'LENNO_synth_loop_bass_rolling_125_Bmin_v2.wav',
#  'LENNO_synth_loop_run_up_114_Emin_v2.wav',
#  'LENNO_synth_loop_disney_109_G#min_v2.wav',
#  'LENNO_drum_fill_together_109_v2.wav',
#  'LENNO_drum_loop_top_rock_it_116_v2.wav',
#  'LENNO_drum_loop_top_groove_112_v2.wav',
#  'LENNO_drum_loop_top_good_109_v2.wav',
#  'LENNO_drum_loop_top_take_me_back_122_v2.wav',
#  'LENNO_synth_juno_bass_G1_v2.wav',
#  'LENNO_synth_brassy_prophet_bass_G1_v2.wav',
#  'LENNO_synth_my_favorite_juno_sound_C2_v2.wav',
#  'LENNO_synth_brassy_prophet_bass_C2_v2.wav',
#  'LENNO_sample_loop_big_125_Bmin_v2.wav',
#  'RKU_BME_Drum_Loop_MessUp_80.wav',
#  'SO_DR_synth_chord_Dmin.wav',
#  'SO_DR_organ_chord_Cmaj.wav',
#  'SO_DR_fx_bird_call_wet.wav',
#  'SO_DR_djemble_open.wav',
#  'SO_DR_cowbell_wet.wav',
#  'SO_DR_snare_tight.wav',
#  'SO_DR_125_piano_chords_kingston_Amin.wav',
#  'SO_DR_82_piano_ups_babylon_Cmaj.wav',
#  'SO_DR_130_guitar_wah_montego_Amin.wav',
#  'SO_DR_125_guitar_rhythm_kingston_Amin.wav',
#  'SO_DR_125_drum_loop_perc_steppa.wav',
#  'SO_DR_80_melodic_stack_bashment_yellow_Gmin.wav',
#  'SO_DR_130_wurli_ups_montego_Amin.wav',
#  'SO_DR_82_wurli_chords_babylon_Cmaj.wav',
#  '82BPM_DVLFX_LAUGH.wav',
#  '125BPM_DVLFX_LAUGH_02.wav',
#  'FMT_-_Am_-_Dr.Dre_Lead.wav',
#  'FMT_-_C#m_-_Block_Synth_Riff.wav',
#  'FMT_-_121_-_Funky_Breakbeat.wav',
#  'FMT_-_112_-_Booty_Bass_Beat__Dm_.wav',
#  'FMT_-_120_-_Booty_Bass_Beat___Dm_.wav',
#  'FMT_-_Am_-_Slap_That_Biatch__Vintage_Wet_.wav',
#  'FMT_-_Fm_-_Disco_Groove.wav',
#  'FMT_-_Gm_-_110__-_Its_About_the_Funk__Talkbox_.wav',
#  'FMT_-_Dm_-_C_-_Gm_-_A#m_-_Skunk_Chords.wav',
#  'FMT_-_Gm_-_Warm_Wah_Rythm.wav',
#  'FMT_-_Gm_-_Pick_Up_Yo.wav',
#  'JS_176bpm_Am_KeepOnMoving_Chorus2_Dry.wav',
#  'JS_115bpm_Am_Coma_Bridge_FX.wav',
#  'APASHE_fx_horn_brass_F#.wav',
#  'SOUTHSIDE_808_punch_F.wav',
#  'SOUTHSIDE_percussion_og_cow.wav',
#  'DSS_vocal_fx_trill_high.wav',
#  'DSS_130_spanish_vocal_hook_have_you_tonight_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_want_you_4_me_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_all_of_you_stack_dry.wav',
#  'DSS_130_spanish_vocal_hook_cant_have_it_stack_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_vino_bueno_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_mamacita_stack_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_aries_double_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_aries_stack_dry_Gm.wav',
#  'DSS_130_spanish_vocal_hook_do_it_solo_lo_harm_wet_Gm.wav',
#  'DSS_130_spanish_vocal_hook_aries_stack_wet_Gm.wav',
#  'DSS_130_spanish_vocal_hook_vino_bueno_wet_Gm.wav',
#  'DSS_130_spanish_vocal_hook_by_the_pool_stack_wet_Gm.wav',
#  'DSS_130_spanish_vocal_hook_light_of_the_moon_double_wet_Gm.wav',
#  'DSS_100_spanish_vocal_hook_free_wet_Am.wav',
#  'CSV_90_vocal_dont_you_try_Em.wav',
#  'CSV_75_guitar_gimme_gimme_6_8_Am.wav',
#  'CSV_75_vintage_soul_stack_gimme_gimme_6_8_Am.wav',
#  'CSV_75_vintage_soul_stack_gimme_more_6_8_Am.wav',
#  'SDP_70_songstarter_coocachoo_E.wav',
#  'NEZ_RIO_vocal_loop_boys_choir_140_Emin.wav',
#  'RU_IL_arrhythmic_murkey_ripple_Cmaj.wav',
#  'hvt_120_materialise_vrs1_Cm.wav',
#  'MOGUAI_126_fx_sixes.wav',
#  '19_TA_Bass_Hit_124_D.wav',
#  '02_TA_Bass_Hit_124_E.wav',
#  '10_TA_Hat_Hit.wav',
#  '09_TA_Kick_Hit_G.wav',
#  '09_TA_Drum_Loop_124_Top.wav',
#  '02_TA_Drum_Loop_124_Full.wav',
#  'TA_Vocal_Loop_124_D.wav',
#  '20_TA_Bass_Loop_124_A_Wet.wav',
#  '08_TA_Bass_Loop_124_B_Wet.wav',
#  '02_TA_Bass_Loop_124_E_Wet.wav',
#  '05_TA_Synth_Loop_124_D_Wet.wav',
#  'FSHR2_Bass_Hit_02_D#.wav',
#  'FSHR2_Bass_Hit_08_F.wav',
#  'FSHR2_HiHats_01.wav',
#  'FSHR2_Kick_10_G#.wav',
#  'FSHR2_Drum_Loop_06_Top_125.wav',
#  'FSHR2_Kit3_Drop_Lead_WET_124_Dm.wav',
#  'FSHR2_Kit3_Mixdown_124_Dm.wav',
#  'FSHR2_Kit3_Mixdown_124_Dm-24b.wav',
#  'FSHR2_Kit3_Crash.wav',
#  'FSHR2_Kit3_Drop_Bass_DRY_124_Dm.wav',
#  'FSHR2_Kit5_Fills_125.wav',
#  'FSHR2_Kit5_Snare_Roll_125.wav',
#  'FSHR2_Kit5_Top_Loop_125.wav',
#  'FSHR2_Kit5_Crash.wav',
#  'FSHR2_Kit2_Kick.wav',
#  'FSHR2_Kit2_FX_3.wav',
#  'FSHR2_Kit1_Alarm_Synth_WET_124_Gm.wav',
#  'FSHR2_Kit1_Fx_1.wav',
#  'FSHR2_Kit1_Kick_2.wav',
#  'FSHR2_Kit1_Vox_1_124_Gm.wav',
#  'FSHR2_Kit6_Top_Loop_124.wav',
#  'FSHR2_Kit6_Mixdown_124_Gm.wav',
#  'FSHR2_Kit4_Drop_Lead_WET_125_Em.wav',
#  'FSHR2_Synth_Loop_08_DRY_125_Bm.wav',
#  'BOB_SINCLAR_fx_fill_tambourine_125.wav',
#  'BOB_SINCLAR_vocal_loop_funky_lala_128.wav',
#  'BOB_SINCLAR_vocal_one_shot_ouhhh_128.wav',
#  'BOB_SINCLAR_drum_loop_kick_heavy_125.wav',
#  'BOB_SINCLAR_drum_loop_kick_fuck_the_disco_126.wav',
#  'BOB_SINCLAR_percussion_loop_beat_root_house_125.wav',
#  'BOB_SINCLAR_percussion_loop_conga_africa_126.wav',
#  'BOB_SINCLAR_percussion_loop_shaker_disco_120.wav',
#  'BOB_SINCLAR_percussion_loop_intro_conga_africa_126.wav',
#  'BOB_SINCLAR_percussion_loop_beat_burning_03_hihat_125.wav',
#  'BOB_SINCLAR_percussion_loop_africanism_live_02_128.wav',
#  'BOB_SINCLAR_percussion_loop_beat_ragga_01_126.wav',
#  'BOB_SINCLAR_bass_sequence_03_i_feel_love_125_Bbmin.wav',
#  'BOB_SINCLAR_bass_sequence_04_i_feel_love_125_Gmin.wav',
#  'TTS_MK_V2_ONESHOT_VOX_HADelay_124_Fmin.wav',
#  'MVH_Hat_05_High.wav',
#  'MVH_Drum_Loop_16_Tribal_126_Tops.wav',
#  'MVH_Bass_Loop_14_Rattley_126_Cm.wav',
#  'MVH_Synth_Loop_20_Rythmic_126_E.wav',
#  'MVH_Synth_Loop_18_Atmospheric_Wet_126_C#m.wav',
#  'DHM_Kit_05_Reverse1_126_Am.wav',
#  'DHM_Kit_05_Bass_Loop_Break_126_Am.wav',
#  'DHM_Kit_05_Vocal_Break_Wet_126_Am.wav',
#  'DHM_Kit_05_Kick.wav',
#  'DHM_Kit_05_Hats.wav',
#  'MVH_Kit_01_Reverse_126_Fm.wav',
#  'DHM_Kit_02_Vocal_Talk_Effected_126_A#m.wav',
#  'DHM_Kit_03_Vocal_Main_Low_Wet_126_Bm.wav',
#  'DHM_Kit_03_Arp_Loop_126_Bm.wav',
#  'DHM_Kit_03_Kick.wav',
#  'DECAP_percussion_one_shot_breath_lower.wav',
#  'DECAP_808_short_fat_distorted_rumble_C.wav',
#  'FL_FBH_125_Drum_Loop_Buildup_01.wav',
#  'FL_FBH_125_Drum_Loop_Buildup_02.wav',
#  'FL_FBH_125_Drum_Loop_Kick_20.wav',
#  'FL_FBH_125_Drum_Loop_Top_06.wav',
#  'FL_FBH_125_Drum_Loop_Full_09.wav',
#  'FL_FBH_125_Drum_Loop_Kick_10.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Lick_It.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Sexy_Yeah.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Dripping_Drops.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Dont_Sleep.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Money.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Take_It_Off_Baby.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Call_Back.wav',
#  'FL_FBH_125_Vocal_Loop_Phrase_Come_On.wav',
#  'FL_FBH_Kick_One_Shot_10.wav',
#  'FL_FBH_Kick_One_Shot_19.wav',
#  'FL_FBH_125_Bass_Loop_01_E.wav',
#  'FL_FBH_125_Bass_Loop_03_F#.wav',
#  'Kit_1_-_Top_Loop_126_BPM_Amin.wav',
#  'Kit_1_-_Kick_126_BPM_Amin.wav',
#  'fh_125_vocal_loop_given_Dmin.wav',
#  'fh_125_synth_loop_daftifh_C#min.wav',
#  'SOPHIE_sub_with_kick_05_F#.wav',
#  'SOUTHSIDExPVLACE_808_hypoxia_C.wav',
#  'SOUTHSIDExPVLACE_808_angst_C.wav',
#  'LSPC_Vocal_Atmosphere_10_115BPM_C.wav',
#  'LSPC_Vocal_Atmosphere_06_115BPM_G.wav',
#  'OS_VTS2_Maybe_It_s_Love.wav',
#  'OS_VTS2_I_Still_Love_You.wav',
#  'STINT_vocal_choir_idea_124_C#maj.wav',
#  'SVD_126_drum_fill_cuba.wav',
#  'SVD_128_top_loop_techno.wav',
#  'SVD_hihat_essential.wav',
#  'SO_HS_fx_owl_hoot.wav',
#  'SO_HS_fx_noise_swoop.wav',
#  'SO_HS_clap_tite_slap.wav',
#  'SO_HS_clap_old_faithful.wav',
#  'SO_HS_kick_right_as_rain.wav',
#  'SO_HS_kick_super_clean.wav',
#  'SO_HS_120_texture_loop_vinyl_crackle.wav',
#  'SO_HS_116_perc_loop_back_alley.wav',
#  'SO_HS_120_perc_loop_conga_groove.wav',
#  'SO_HS_118_drum_loop_classic_cassette.wav',
#  'SO_HS_120_drum_loop_conga_groove_kit.wav',
#  'SO_HS_120_drum_loop_crushed_up_break_clap.wav',
#  'SO_HS_112_vocal_choppy_struttin_Cmin.wav',
#  'SO_HS_120_synth_stutter_playful_Cmin.wav',
#  'SO_HS_112_bass_glidey_Ebmaj.wav',
#  'SO_HS_122_bass_echoed_Fmaj.wav',
#  'SO_HS_120_top_loop_808_clone_perc_snares.wav',
#  'SO_HS_118_top_loop_exotic_n_crunchy.wav',
#  'SO_HS_120_top_loop_rim_stick_clav_rhythm.wav',
#  'SO_HS_120_top_loop_et_phone_home_perc_top.wav',
#  'SO_HS_116_top_loop_back_alley.wav',
#  'SO_HS_120_melodic_stack_dizzy_love_Dmin.wav',
#  'dhs_open_hat_one_shot_synthetic_theone.wav',
#  'dhs_percussion_rim_one_shot_silverring.wav',
#  'dhs_clap_one_shot_synthetic_entri.wav',
#  'dhs_kick_one_shot_synthetic_low_ohmyattack.wav',
#  'dhs_123_drum_loop_vinnifrost_top.wav',
#  'dhs_123_drum_loop_flaka_full.wav',
#  'dhs_123_vocal_loop_hey2_C#min.wav',
#  'dhs_127_bass_synth_loop_depth_Amin.wav',
#  'ah_acid120_slimboyfat2_F.wav',
#  'SOUNDDOCTRINE_processional_one_shot_Organ_chord_G7.wav',
#  'SOUNDDOCTRINE_processional_one_shot_vocal_melody_Bmaj.wav',
#  'RT_Dynasty_Electric_Theremin_1_Synths_Jenny_Electrik_146_A_Minor_one_shot.wav',
#  'SR_PH_128_percussion_loop_story.wav',
#  'SR_PH_125_percussion_loop_motion.wav',
#  'SR_PH_kick_high.wav',
#  'SR_PH_percussion_tough.wav',
#  'NOIZU_laser_one_shot_03_124.wav',
#  'NOIZU_laser_one_shot_01_124.wav',
#  'NOIZU_white_noise_medium_02_124.wav',
#  'NOIZU_hihat_open_one_shot_07.wav',
#  'NOIZU_hihat_closed_one_shot_10.wav',
#  'NOIZU_snare_loop_riser_09_124.wav',
#  'NOIZU_snare_loop_riser_10_124.wav',
#  'NOIZU_snare_loop_riser_01_124.wav',
#  'NOIZU_ride_one_shot_06.wav',
#  'NOIZU_bass_one_shot_moog_04_F.wav',
#  'osr_vocal_loop_i_got_the_feelin_128_Fm.wav',
#  'osr_drum_break_loop_wikid_128.wav',
#  'osr_drum_break_loop_gaia_128.wav',
#  'osr_drum_break_loop_meat_128.wav',
#  'osr_drum_break_loop_pong_128.wav',
#  'osr_drum_break_loop_funkeh_128.wav',
#  'osr_drum_break_loop_brklyn_128.wav',
#  'osr_melodic_loop_crunch_128_Fm.wav',
#  'osr_melodic_loop_carra_128_Fm.wav',
#  'JPGC_vocal_josh_pan_crazy.wav',
#  'FTH_FX_16_Impact_128.wav',
#  'SH_THM_24_Synth_Loop_125_F.wav',
#  'SH_TCM_10_Top_Loop_125.wav',
#  'WONDAGURL_snap_03.wav',
#  'EVIGAN_percussion_fill_conga.wav',
#  'EVIGAN_percussion_loop_shaker_chains_76.wav',
#  'EVIGAN_drum_loop_80s_but_new_119.wav',
#  'EVIGAN_drum_loop_old_man_maggy_120.wav',
#  'EVIGAN_snap_one_shot_outdoors.wav',
#  'EVIGAN_mouth_whistle.wav',
#  'EVIGAN_fx_sweep_one_shot_classic.wav',
#  'SERJ_TANKIAN_drum_loop_cannister_100.wav',
#  'SERJ_TANKIAN_drum_loop_heavy_100.wav',
#  'SERJ_TANKIAN_drum_loop_both_lasers_100.wav',
#  'SERJ_TANKIAN_orchestra_loop_violin_100_Cmin.wav',
#  'SERJ_TANKIAN_orchestra_loop_solo_violins_100_Cmin.wav',
#  'SERJ_TANKIAN_orchestra_loop_cello_100_Cmin.wav',
#  'SERJ_TANKIAN_orchestra_loop_cello_mongol_100_Cmin.wav',
#  'SERJ_TANKIAN_keys_loop_hell_100_Cmin.wav',
#  'SERJ_TANKIAN_piano_loop_sorrowful_85_Gmin.wav',
#  'SERJ_TANKIAN_piano_loop_building_100_Cmin.wav',
#  'SERJ_TANKIAN_bass_loop_ridem_100_Cmin.wav',
#  'SERJ_TANKIAN_acoustic_guitar_loop_arabic_01_100_Cmin.wav',
#  'SERJ_TANKIAN_acoustic_guitar_loop_arabic_02_100_Cmin.wav',
#  'SERJ_TANKIAN_electric_guitar_loop_walls_100_Cmin.wav',
#  'SERJ_TANKIAN_electric_guitar_loop_under_water_100_Cmin.wav',
#  'SERJ_TANKIAN_electric_guitar_loop_picking_100_Cmin.wav',
#  'SERJ_TANKIAN_electric_guitar_loop_hard_100_Cmin.wav',
#  'SERJ_TANKIAN_vocal_phrase_sung_aaaah_reverb_Cmin.wav',
#  'SERJ_TANKIAN_vocal_phrase_your_tears_and_fears_all_melt_away_100_Cmin.wav',
#  'SERJ_TANKIAN_fx_loop_alien_teleportation_140_Cmin.wav',
#  'SC_DS_120_strings_melody_hooky_legato_Gmin.wav',
#  'SC_DS_120_strings_stabs_swinging_upward_sting_Gmin.wav',
#  'SC_DS_120_strings_stabs_glissando_hook_rising_end_Gmin.wav',
#  'SC_DS_125_strings_riff_median_repeation_Amin.wav',
#  'SC_DS_118_strings_melody_legato_quarter_note_pickup_ending_Bmin.wav',
#  'SO_DS_110_string_stack_azuki_Amin.wav',
#  'SO_DS_110_viola_stack_chartreuse_Dmin.wav',
#  'DIASPORA_requinto_one_shot_bongo_roll_short.wav',
#  'DIASPORA_requinto_percussion_loop_2_bachata_dry_130_bpm.wav',
#  'DIASPORA_requinto_melodic_loop_7_full_bachata_123_bpm_Amin.wav',
#  'DIASPORA_requinto_melodic_loop_15_full_bachata_130_Dmin.wav',
#  'DIASPORA_requinto_melodic_loop_10_full_bachata_135_bpm_Bbmin.wav',
#  'DIASPORA_requinto_melodic_loop_6_full_bachata_145_bpm_Emin.wav',
#  'DIASPORA_requinto_melodic_loop_2_lead_guitar_bachata_130_bpm_Amin.wav',
#  'DIASPORA_requinto_melodic_loop_6_lead_guitar_bachata_145_bpm_Emin.wav',
#  'DIASPORA_requinto_melodic_loop_5_swing_guitar_bachata_145_bpm_Emin.wav',
#  'DIASPORA_requinto_melodic_loop_10_lead_guitar_bachata_135_bpm_Bbmin.wav',
#  'DIASPORA_requinto_melodic_loop_7_lead_guitar_bachata_123_bpm_Amin.wav',
#  'DIASPORA_requinto_melodic_loop_7_rhythm_guitar_bachata_123_bpm_Amin.wav',
#  '108_-_Am_-_Disco_Guitar_03.wav',
#  '108_-_Am_-_Disco_Guitar_04.wav',
#  '108_-_Am_-_Wah_Guitar_01.wav']

# %%
# Get full file paths for Splice samples for eventual audio processing
splice_files_path = glob.glob(SPLICE_SAMPLES_PATH + '/**/*.wav', recursive=True)
full_file_path_map = { sample : sample_path for sample, sample_path in zip(splice_files, splice_files_path)}

# %% [markdown]
# ## Custom sample class
# Every sample will be stored as one of our custom Sample objects, with the following required attributes:
# - Name
# - Tempo
# - Key
# - One shot
# - Full path
# - Instrument (leaving this one out for now)

# %%
from sample_processor import Sample

# Convert all Splice files to custom Sample object
sample_objects = []
for sample_file in splice_files:
    full_path = full_file_path_map[sample_file]
    new_sample = Sample(sample_file, full_path)
    sample_objects.append(new_sample)

# %%
len(sample_objects)
# Out:
# 931

# %%
# Verify correct Sample object creation for loop sample
test_sample = sample_objects[10]

sample_output = (
    f'Name: {test_sample.name}\n'
    f'Tempo: {test_sample.tempo}\n'
    f'Key: {test_sample.key}\n'
    f'One Shot: {test_sample.one_shot}\n'
    f'Full path: {test_sample.full_path}'
)

print(sample_output)
# Out:
# Name: SPINNIN_melody_loop_intro_wubs_126_Cmaj.wav
# Tempo: 126
# Key: C major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_intro_wubs_126_Cmaj.wav

# %%
# Verify correct Sample object creation for one shot sample
test_sample_one_shot = sample_objects[20]

sample_output = (
    f'Name: {test_sample_one_shot.name}\n'
    f'Tempo: {test_sample_one_shot.tempo}\n'
    f'Key: {test_sample_one_shot.key}\n'
    f'One Shot: {test_sample_one_shot.one_shot}\n'
    f'Full path: {test_sample_one_shot.full_path}'
)

print(sample_output)
# Out:
# Name: SPINNIN_uplifter_one_shot_cool.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_fx/SPINNIN_sweeps/SPINNIN_uplifter_one_shot_cool.wav

# %%
# Verify correct Sample object creation for all Splice samples
for sample in sample_objects:
    sample_output = (
        f'Name: {sample.name}\n'
        f'Tempo: {sample.tempo}\n'
        f'Key: {sample.key}\n'
        f'One Shot: {sample.one_shot}\n'
        f'Full path: {sample.full_path}'
    )
    print(sample_output)
    print('--------------------------------------------------\n')
# Out:
# Name: SPINNIN_synth_one_shot_high_brass_Bmaj.wav
# Tempo: None
# Key: B major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_synth_one_shots/SPINNIN_synth_one_shot_high_brass_Bmaj.wav
# --------------------------------------------------
#
# Name: SPINNIN_synth_one_shot_classic_stab_Emaj.wav
# Tempo: None
# Key: E major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_synth_one_shots/SPINNIN_synth_one_shot_classic_stab_Emaj.wav
# --------------------------------------------------
#
# Name: SPINNIN_synth_one_shot_short_piano_Fmin.wav
# Tempo: None
# Key: f minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_synth_one_shots/SPINNIN_synth_one_shot_short_piano_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_synth_one_shot_brass_hit_Emaj.wav
# Tempo: None
# Key: E major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_synth_one_shots/SPINNIN_synth_one_shot_brass_hit_Emaj.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_falling_bassline_126_Emin.wav
# Tempo: 126
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_falling_bassline_126_Emin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_dirty_wubs_126_Fmin.wav
# Tempo: 126
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_dirty_wubs_126_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_riddim_cowbell_lead_126_Fmin.wav
# Tempo: 126
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_riddim_cowbell_lead_126_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_clubby_bassline_126_Fmin.wav
# Tempo: 126
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_clubby_bassline_126_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_uk_bass_126_Emin.wav
# Tempo: 126
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_uk_bass_126_Emin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_warehouse_wobble_stab_125_Fmin.wav
# Tempo: 125
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_warehouse_wobble_stab_125_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_intro_wubs_126_Cmaj.wav
# Tempo: 126
# Key: C major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_intro_wubs_126_Cmaj.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_cruisin_bass_128_Emin.wav
# Tempo: 128
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_cruisin_bass_128_Emin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_dirty_bass_126_Fmin.wav
# Tempo: 126
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_dirty_bass_126_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_melody_loop_fat_and_bouncy_126_Fmin.wav
# Tempo: 126
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melody_loops/SPINNIN_melody_loop_fat_and_bouncy_126_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_top_loop_dance_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_top_loops/SPINNIN_drum_top_loop_dance_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_clap_one_shot_thick.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_one_shots/SPINNIN_claps/SPINNIN_clap_one_shot_thick.wav
# --------------------------------------------------
#
# Name: SPINNIN_kick_one_shot_punch.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_one_shots/SPINNIN_kicks/SPINNIN_kick_one_shot_punch.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_loop_deep_full_loop_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_loops/SPINNIN_drum_loop_deep_full_loop_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_fill_loop_gunshot_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_fills/SPINNIN_drum_fill_loop_gunshot_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_vocal_one_shot_oooh.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_vocals/SPINNIN_vocal_one_shot_oooh.wav
# --------------------------------------------------
#
# Name: SPINNIN_uplifter_one_shot_cool.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Bass House Sample Pack/SPINNIN_BASS_HOUSE_sample_pack/SPINNIN_fx/SPINNIN_sweeps/SPINNIN_uplifter_one_shot_cool.wav
# --------------------------------------------------
#
# Name: SC_RH_152_horns_chords_skanks_classic_Cmaj.wav
# Tempo: 152
# Key: C major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Reggae Horns/Audio/loops/152_bpm/SC_RH_152_horns_chords_skanks_classic_Cmaj.wav
# --------------------------------------------------
#
# Name: CVS_beat_loop_01_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_loops/CVS_drum_loops/CVS_beat_loops/CVS_beat_loop_01_124.wav
# --------------------------------------------------
#
# Name: CVS_beat_loop_03_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_loops/CVS_drum_loops/CVS_beat_loops/CVS_beat_loop_03_124.wav
# --------------------------------------------------
#
# Name: CVS_percussion_loop_07_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_loops/CVS_drum_loops/CVS_percussion_loops/CVS_percussion_loop_07_124.wav
# --------------------------------------------------
#
# Name: CVS_tom_loop_04_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_loops/CVS_drum_loops/CVS_tom_loops/CVS_tom_loop_04_124.wav
# --------------------------------------------------
#
# Name: CVS_synth_one_shot_11_F#.wav
# Tempo: None
# Key: G- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_tonal_one_shots/CVS_synth/CVS_synth_one_shot_11_F#.wav
# --------------------------------------------------
#
# Name: CVS_synth_one_shot_09_F#.wav
# Tempo: None
# Key: G- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_tonal_one_shots/CVS_synth/CVS_synth_one_shot_09_F#.wav
# --------------------------------------------------
#
# Name: CVS_synth_one_shot_18_B.wav
# Tempo: None
# Key: B major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_tonal_one_shots/CVS_synth/CVS_synth_one_shot_18_B.wav
# --------------------------------------------------
#
# Name: CVS_synth_one_shot_01_G.wav
# Tempo: None
# Key: G major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_tonal_one_shots/CVS_synth/CVS_synth_one_shot_01_G.wav
# --------------------------------------------------
#
# Name: CVS_bass_one_shot_14_F.wav
# Tempo: None
# Key: F major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_tonal_one_shots/CVS_bass/CVS_bass_one_shot_14_F.wav
# --------------------------------------------------
#
# Name: CVS_bass_one_shot_20_F.wav
# Tempo: None
# Key: F major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_tonal_one_shots/CVS_bass/CVS_bass_one_shot_20_F.wav
# --------------------------------------------------
#
# Name: CVS_fx_riser_one_shot_09.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_fx_one_shots/CVS_fx_risers/CVS_fx_riser_one_shot_09.wav
# --------------------------------------------------
#
# Name: CVS_fx_riser_one_shot_12.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_fx_one_shots/CVS_fx_risers/CVS_fx_riser_one_shot_12.wav
# --------------------------------------------------
#
# Name: CVS_vocal_one_shot_08.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_vocal_one_shots/CVS_vocal_one_shot_08.wav
# --------------------------------------------------
#
# Name: CVS_clap_one_shot_06.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_drum_one_shots/CVS_claps/CVS_clap_one_shot_06.wav
# --------------------------------------------------
#
# Name: CVS_snare_one_shot_01.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_drum_one_shots/CVS_snares/CVS_snare_one_shot_01.wav
# --------------------------------------------------
#
# Name: CVS_tom_conga_one_shot_04.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_drum_one_shots/CVS_toms_and_congas/CVS_tom_conga_one_shot_04.wav
# --------------------------------------------------
#
# Name: CVS_808_one_shot_04_C.wav
# Tempo: None
# Key: C major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Claude VonStroke Sample Pack/CLAUDE_VON_STROKE_labeled_edited_processed/CLAUDE_VON_STROKE_one_shots/CVS_drum_one_shots/CVS_808s/CVS_808_one_shot_04_C.wav
# --------------------------------------------------
#
# Name: KSHMR_Indian_Violin__128__F#m_.wav
# Tempo: 128
# Key: g- minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/KSHMR_Indian_Violin__128__F#m_.wav
# --------------------------------------------------
#
# Name: KSHMR_Cinematic_Drums_100BPM_02.wav
# Tempo: 100
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/KSHMR_Cinematic_Drums_100BPM_02.wav
# --------------------------------------------------
#
# Name: KSHMR_Natural_Ambiance_05_-_Rain.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/FX_Elements/Ambiance_Natural/KSHMR_Natural_Ambiance_05_-_Rain.wav
# --------------------------------------------------
#
# Name: KSHMR_Choir_02_-_C_Major_High.wav
# Tempo: None
# Key: C major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/Live_Instruments/Orchestral_Instruments/Choir/KSHMR_Choir_02_-_C_Major_High.wav
# --------------------------------------------------
#
# Name: KSHMR_Choir_06_-_F#_Major.wav
# Tempo: None
# Key: G- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/Live_Instruments/Orchestral_Instruments/Choir/KSHMR_Choir_06_-_F#_Major.wav
# --------------------------------------------------
#
# Name: KSHMR_Choir_03_-_C_Major_Low.wav
# Tempo: None
# Key: C major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/Live_Instruments/Orchestral_Instruments/Choir/KSHMR_Choir_03_-_C_Major_Low.wav
# --------------------------------------------------
#
# Name: KSHMR_Choir_05_-_F_Minor.wav
# Tempo: None
# Key: f minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/Live_Instruments/Orchestral_Instruments/Choir/KSHMR_Choir_05_-_F_Minor.wav
# --------------------------------------------------
#
# Name: KSHMR_Choir_04_-_C#_Major.wav
# Tempo: None
# Key: D- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 2/Live_Instruments/Orchestral_Instruments/Choir/KSHMR_Choir_04_-_C#_Major.wav
# --------------------------------------------------
#
# Name: MAT_ZO_hihat_closed_06.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Mat Zo's Mad Zoo Drums Vol. 1/MAT_ZO_sample_pack/MAT_ZO_drum_one_shots/MAT_ZO_hihats/MAT_ZO_closed_hihats/MAT_ZO_hihat_closed_06.wav
# --------------------------------------------------
#
# Name: MAT_ZO_kick_109.wav
# Tempo: 109
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Mat Zo's Mad Zoo Drums Vol. 1/MAT_ZO_sample_pack/MAT_ZO_drum_one_shots/MAT_ZO_kicks/MAT_ZO_kick_109.wav
# --------------------------------------------------
#
# Name: MAT_ZO_snare_094.wav
# Tempo: 94
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Mat Zo's Mad Zoo Drums Vol. 1/MAT_ZO_sample_pack/MAT_ZO_drum_one_shots/MAT_ZO_snares/MAT_ZO_snare_094.wav
# --------------------------------------------------
#
# Name: MAT_ZO_drum_loop_11_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Mat Zo's Mad Zoo Drums Vol. 1/MAT_ZO_sample_pack/MAT_ZO_drum_loops/MAT_ZO_drum_loop_11_124.wav
# --------------------------------------------------
#
# Name: TFH_Cowbell_01_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Percussion_Loops/TFH_Cowbell_01_124.wav
# --------------------------------------------------
#
# Name: TFH_Reverse_Crash_FX_01_X.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/FX/TFH_Reverse_Crash_FX_01_X.wav
# --------------------------------------------------
#
# Name: TFH_Synth_Hit_FX_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/FX/TFH_Synth_Hit_FX_124.wav
# --------------------------------------------------
#
# Name: TFH_Crash_FX_03_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/FX/TFH_Crash_FX_03_124.wav
# --------------------------------------------------
#
# Name: TFH_Mid_Snare_Fill_03.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Drum_Fills/TFH_Mid_Snare_Fill_03.wav
# --------------------------------------------------
#
# Name: TFH_Mid_Snare_Fill_06.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Drum_Fills/TFH_Mid_Snare_Fill_06.wav
# --------------------------------------------------
#
# Name: TFH_Long_Snare_Fill_03.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Drum_Fills/TFH_Long_Snare_Fill_03.wav
# --------------------------------------------------
#
# Name: TFH_Drum_Fill_01.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Drum_Fills/TFH_Drum_Fill_01.wav
# --------------------------------------------------
#
# Name: TFH_Short_Snare_Fill_02.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Drum_Fills/TFH_Short_Snare_Fill_02.wav
# --------------------------------------------------
#
# Name: TFH_Top_Loop_10_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Top_Loops/TFH_Top_Loop_10_124.wav
# --------------------------------------------------
#
# Name: TFH_Music_Housefilter_124_Em.wav
# Tempo: 124
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Music_Loops/TFH_Music_Housefilter_124_Em.wav
# --------------------------------------------------
#
# Name: TFH_Music_Classic_Synth_Hit_01_124_Am.wav
# Tempo: 124
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Music_Loops/TFH_Music_Classic_Synth_Hit_01_124_Am.wav
# --------------------------------------------------
#
# Name: TFH_Music_Classic_Synth_03_124_Fm.wav
# Tempo: 124
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Music_Loops/TFH_Music_Classic_Synth_03_124_Fm.wav
# --------------------------------------------------
#
# Name: TFH_Vocal_Loop_08_124_Am.wav
# Tempo: 124
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Vocal_Loops/TFH_Vocal_Loop_08_124_Am.wav
# --------------------------------------------------
#
# Name: TFH_Vocal_Loop_15_124_X.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Vocal_Loops/TFH_Vocal_Loop_15_124_X.wav
# --------------------------------------------------
#
# Name: TFH_Vocal_Loop_12_124_Am.wav
# Tempo: 124
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Vocal_Loops/TFH_Vocal_Loop_12_124_Am.wav
# --------------------------------------------------
#
# Name: TFH_Bass_Loop_16_124_Dm.wav
# Tempo: 124
# Key: d minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Bass_Loops/TFH_Bass_Loop_16_124_Dm.wav
# --------------------------------------------------
#
# Name: TFH_Bass_Loop_08_124_Cm.wav
# Tempo: 124
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Bass_Loops/TFH_Bass_Loop_08_124_Cm.wav
# --------------------------------------------------
#
# Name: TFH_Hat_Loop_16_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Hat_Loops/TFH_Hat_Loop_16_124.wav
# --------------------------------------------------
#
# Name: TFH_Hat_Loop_18_124.wav
# Tempo: 124
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Tech Funk House by Earth and Days/BS047_Tech_Funk_House_by_Earth_and_Days-WAV/Tech_Funk_House_by_Earthndays-WAV/Hat_Loops/TFH_Hat_Loop_18_124.wav
# --------------------------------------------------
#
# Name: hn_hat_hausopen.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/one_shots/hats/hn_hat_hausopen.wav
# --------------------------------------------------
#
# Name: hn_fx_bombah.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/fx/hn_fx_bombah.wav
# --------------------------------------------------
#
# Name: hn_fx_layzer.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/fx/hn_fx_layzer.wav
# --------------------------------------------------
#
# Name: hn_mus125_filta1_Em.wav
# Tempo: 125
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/music_loops/hn_mus125_filta1_Em.wav
# --------------------------------------------------
#
# Name: hn_mus125_straw1_A#m.wav
# Tempo: 125
# Key: b- minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/music_loops/hn_mus125_straw1_A#m.wav
# --------------------------------------------------
#
# Name: hn_mus125_stride3_Gm.wav
# Tempo: 125
# Key: g minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/music_loops/hn_mus125_stride3_Gm.wav
# --------------------------------------------------
#
# Name: hn_mus125_smoothi3_G#m.wav
# Tempo: 125
# Key: a- minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/House Nation/SM48_-_House_Nation_-_Wav/music_loops/hn_mus125_smoothi3_G#m.wav
# --------------------------------------------------
#
# Name: SONNY_D_808_18_C.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_808s/SONNY_D_808_18_C.wav
# --------------------------------------------------
#
# Name: SONNY_D_hihat_open_11.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_hihats/SONNY_D_open_hihats/SONNY_D_hihat_open_11.wav
# --------------------------------------------------
#
# Name: SONNY_D_percussion_05.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_percussion/SONNY_D_percussion_05.wav
# --------------------------------------------------
#
# Name: SONNY_D_kick_09.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_kicks/SONNY_D_kick_09.wav
# --------------------------------------------------
#
# Name: SONNY_D_snare_10.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_snares/SONNY_D_snare_10.wav
# --------------------------------------------------
#
# Name: SONNY_D_snare_04.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_snares/SONNY_D_snare_04.wav
# --------------------------------------------------
#
# Name: SONNY_D_snare_14.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_drums/SONNY_D_snares/SONNY_D_snare_14.wav
# --------------------------------------------------
#
# Name: SONNY_D_vocal_02.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sonny Digital Drumkit/SONNY_D_drum_kit/SONNY_D_vocals/SONNY_D_vocal_02.wav
# --------------------------------------------------
#
# Name: KSHMR_Song_Starter_Hip_Hop_Mustard_90_Am.wav
# Tempo: 90
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Song_Starters/KSHMR_Song_Starters_Hip_Hop/KSHMR_Song_Starter_Hip_Hop_Mustard_90_Am.wav
# --------------------------------------------------
#
# Name: KSHMR_Song_Starter_Hip_Hop_Holy_Water_104_Dm.wav
# Tempo: 104
# Key: d minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Song_Starters/KSHMR_Song_Starters_Hip_Hop/KSHMR_Song_Starter_Hip_Hop_Holy_Water_104_Dm.wav
# --------------------------------------------------
#
# Name: KSHMR_Song_Starter_09_Breathing_Texture_140_Dm-F-Em-D#.wav
# Tempo: 140
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Song_Starters/KSHMR_Song_Starters_Main/KSHMR_Song_Starter_09_Breathing_Texture_140_Dm-F-Em-D#.wav
# --------------------------------------------------
#
# Name: KSHMR3_Tom_Fill_11_110_Cinematic.wav
# Tempo: 110
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Drums/KSHMR_Drum_Fills/KSHMR_Tom_Fills/KSHMR3_Tom_Fill_11_110_Cinematic.wav
# --------------------------------------------------
#
# Name: KSHMR_Cymbal_Transition_24_Reverse_03.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Drums/KSHMR_Transitions/KSHMR_Cymbal_Transitions/KSHMR_Cymbal_Transition_24_Reverse_03.wav
# --------------------------------------------------
#
# Name: KSHMR_Big_Kick_12_E.wav
# Tempo: None
# Key: E major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Drums/KSHMR_Drum_One_shots/KSHMR_Kicks/KSHMR_Big_Kicks/KSHMR_Big_Kick_12_E.wav
# --------------------------------------------------
#
# Name: KSHMR_Jungle_Kick_02.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Drums/KSHMR_Drum_One_shots/KSHMR_Kicks/KSHMR_Hip_Hop_kicks/KSHMR_Jungle_Kicks/KSHMR_Jungle_Kick_02.wav
# --------------------------------------------------
#
# Name: KSHMR_Bass_Stab_10_F.wav
# Tempo: None
# Key: F major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Synths/KSHMR_Bass_One_Shots/KSHMR_Bass_Stab/KSHMR_Bass_Stab_10_F.wav
# --------------------------------------------------
#
# Name: KSHMR_Bass_Stab_01_E.wav
# Tempo: None
# Key: E major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Synths/KSHMR_Bass_One_Shots/KSHMR_Bass_Stab/KSHMR_Bass_Stab_01_E.wav
# --------------------------------------------------
#
# Name: KSHMR_Bass_Shot_07_G.wav
# Tempo: None
# Key: G major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Synths/KSHMR_Bass_One_Shots/KSHMR_Bass_Stab/KSHMR_Bass_Shot_07_G.wav
# --------------------------------------------------
#
# Name: KSHMR_Bass_Shot_04_A.wav
# Tempo: None
# Key: A major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Synths/KSHMR_Bass_One_Shots/KSHMR_Bass_Stab/KSHMR_Bass_Shot_04_A.wav
# --------------------------------------------------
#
# Name: KSHMR_Synth_Shot_08_C.wav
# Tempo: None
# Key: C major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Synths/KSHMR_Synth_Shots/KSHMR_Synth_Shot_08_C.wav
# --------------------------------------------------
#
# Name: KSHMR_Choir_05_Opera_Stab_Em.wav
# Tempo: None
# Key: e minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Vocals/KSHMR_Vocals_Adlibs_and_Tones/KSHMR_Choirs/KSHMR_Choir_05_Opera_Stab_Em.wav
# --------------------------------------------------
#
# Name: KSHMR_Vocal_Melody_38_140_Em.wav
# Tempo: 140
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Vocals/KSHMR_Vocals_Loops_and_Melodies/KSHMR_Vocal_Melodies/KSHMR_Vocal_Melody_38_140_Em.wav
# --------------------------------------------------
#
# Name: KSHMR_Indian_Freestyle_Vocal_08_D#m.wav
# Tempo: None
# Key: e- minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Vocals/KSHMR_Vocals_Ethnic/KSHMR_Indian_Vocals/KSHMR_Indian_Vocal_Freestyles/KSHMR_Indian_Freestyle_Vocal_08_D#m.wav
# --------------------------------------------------
#
# Name: KSHMR_Breathing_07_Short_Breath.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_Novelties/KSHMR_Vocals/KSHMR_Vocals_FX/KSHMR_Breathing/KSHMR_Breathing_07_Short_Breath.wav
# --------------------------------------------------
#
# Name: KSHMR_Latin_GTR_Guitar_90_Am.wav
# Tempo: 90
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_World_Sounds/KSHMR_Latin_America/KSHMR_Latin_GTR_Guitar_90_Am.wav
# --------------------------------------------------
#
# Name: KSHMR_Bird_Call_05_Down_C#.wav
# Tempo: None
# Key: D- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_FX/KSHMR_Ambiance_and_Foley/KSHMR_Ambiance_Designed/KSHMR_Bird_Calls/KSHMR_Bird_Call_05_Down_C#.wav
# --------------------------------------------------
#
# Name: KSHMR_Sub_Drop_12_G.wav
# Tempo: None
# Key: G major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_FX/KSHMR_Sub_Drops/KSHMR_Sub_Drop_12_G.wav
# --------------------------------------------------
#
# Name: KSHMR_Reverse_Vocal_02_Am.wav
# Tempo: None
# Key: a minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_FX/KSHMR_Reverse_Instrument_FX/KSHMR_Reverse_Vocals/KSHMR_Reverse_Vocal_02_Am.wav
# --------------------------------------------------
#
# Name: KSHMR_Reverse_Vocal_12_F.wav
# Tempo: None
# Key: F major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_FX/KSHMR_Reverse_Instrument_FX/KSHMR_Reverse_Vocals/KSHMR_Reverse_Vocal_12_F.wav
# --------------------------------------------------
#
# Name: KSHMR_Impact_with_Sweep_03.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_FX/KSHMR_Impacts/KSHMR_Impacts_01_Main/KSHMR_Impact_with_Sweep_03.wav
# --------------------------------------------------
#
# Name: KSHMR_Stab_19_G#.wav
# Tempo: None
# Key: A- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Sounds of KSHMR Vol. 3/KSHMR_processed/KSHMR_FX/KSHMR_Stabs/KSHMR_Stab_19_G#.wav
# --------------------------------------------------
#
# Name: fg_melodic_one_shot_funkbass_Gmin.wav
# Tempo: None
# Key: g minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Future Groove/SKU#SM300_-_SM228_-_Future_Groove/bass_one-shots/fg_melodic_one_shot_funkbass_Gmin.wav
# --------------------------------------------------
#
# Name: fg_kit_futurefunk_bellshine_110_F#maj.wav
# Tempo: 110
# Key: G- major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Future Groove/SKU#SM300_-_SM228_-_Future_Groove/music_kits/fg_kit_futurefunk_110_F#/fg_kit_futurefunk_bellshine_110_F#maj.wav
# --------------------------------------------------
#
# Name: fg_kit_grooveshop_full_110_Fmin.wav
# Tempo: 110
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Future Groove/SKU#SM300_-_SM228_-_Future_Groove/music_kits/fg_kit_grooveshop_110_Fm/fg_kit_grooveshop_full_110_Fmin.wav
# --------------------------------------------------
#
# Name: OLIVER_fx_breath.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_fx/OLIVER_fx/OLIVER_fx_breath.wav
# --------------------------------------------------
#
# Name: OLIVER_fx_stab_hit_D.wav
# Tempo: None
# Key: D major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_fx/OLIVER_fx/OLIVER_fx_stab_hit_D.wav
# --------------------------------------------------
#
# Name: OLIVER_fx_m1_dry_ice_add_delay.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_fx/OLIVER_fx/OLIVER_fx_m1_dry_ice_add_delay.wav
# --------------------------------------------------
#
# Name: OLIVER_fx_reverb_breath.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_fx/OLIVER_fx/OLIVER_fx_reverb_breath.wav
# --------------------------------------------------
#
# Name: OLIVER_noise_fx_vinyl_crackle_01.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_fx/OLIVER_noise_foley/OLIVER_noise_fx_vinyl_crackle_01.wav
# --------------------------------------------------
#
# Name: OLIVER_linn_lm1_one_shot_cowbell_02.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_linn_lm1_definitive/OLIVER_linn_lm1_cowbells/OLIVER_linn_lm1_one_shot_cowbell_02.wav
# --------------------------------------------------
#
# Name: OLIVER_linn_lm1_one_shot_cowbell_01.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_linn_lm1_definitive/OLIVER_linn_lm1_cowbells/OLIVER_linn_lm1_one_shot_cowbell_01.wav
# --------------------------------------------------
#
# Name: OLIVER_clap_one_shot_operator_01.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_claps/OLIVER_clap_one_shot_operator_01.wav
# --------------------------------------------------
#
# Name: OLIVER_one_shot_snare_retro_06.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_snares/OLIVER_snares_retro/OLIVER_one_shot_snare_retro_06.wav
# --------------------------------------------------
#
# Name: OLIVER_one_shot_snare_punchy_10.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_snares/OLIVER_snares_punchy/OLIVER_one_shot_snare_punchy_10.wav
# --------------------------------------------------
#
# Name: OLIVER_one_shot_snare_disco_02.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_snares/OLIVER_snares_disco/OLIVER_one_shot_snare_disco_02.wav
# --------------------------------------------------
#
# Name: OLIVER_percussion_one_shot_cowbell_C.wav
# Tempo: None
# Key: C major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_one_shots/OLIVER_percussion/OLIVER_percussion_one_shot_cowbell_C.wav
# --------------------------------------------------
#
# Name: OLIVER_disco_drum_loop_115.wav
# Tempo: 115
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_disco/OLIVER_disco_drum_loop_115.wav
# --------------------------------------------------
#
# Name: OLIVER_retro_drum_loop_1984_funk_120.wav
# Tempo: 120
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_retro_80s/OLIVER_retro_drum_loop_1984_funk_120.wav
# --------------------------------------------------
#
# Name: OLIVER_hihat_drum_loop_live_115.wav
# Tempo: 115
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_hihat_loops/OLIVER_hihat_drum_loop_live_115.wav
# --------------------------------------------------
#
# Name: OLIVER_fill_drum_loop_100_02.wav
# Tempo: 100
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_fills/OLIVER_fill_drum_loop_100_02.wav
# --------------------------------------------------
#
# Name: OLIVER_percussion_loop_crowd_party_110.wav
# Tempo: 110
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_percussion/OLIVER_percussion_loop_crowd_party_110.wav
# --------------------------------------------------
#
# Name: OLIVER_percussion_loop_disco_cow_120.wav
# Tempo: 120
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_percussion/OLIVER_percussion_loop_disco_cow_120.wav
# --------------------------------------------------
#
# Name: OLIVER_percussion_loop_snap_&_breath_90.wav
# Tempo: 90
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_percussion/OLIVER_percussion_loop_snap_&_breath_90.wav
# --------------------------------------------------
#
# Name: OLIVER_kick_snare_combo_drum_loop_hard_future_103.wav
# Tempo: 103
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_drums/OLIVER_loops/OLIVER_kick_snare_combos/OLIVER_kick_snare_combo_drum_loop_hard_future_103.wav
# --------------------------------------------------
#
# Name: OLIVER_bass_loop_arpeggio_98_C.wav
# Tempo: 98
# Key: C major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_tonal/OLIVER_music_loops/OLIVER_bass_loops/OLIVER_bass_loop_arpeggio_98_C.wav
# --------------------------------------------------
#
# Name: OLIVER_one_shot_bass_C0_04_C.wav
# Tempo: None
# Key: C major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_tonal/OLIVER_bass_one_shots/OLIVER_synth_bass_one_shots_c0/OLIVER_one_shot_bass_C0_04_C.wav
# --------------------------------------------------
#
# Name: OLIVER_live_bass_one_shot_hammer_02_F#.wav
# Tempo: None
# Key: G- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_tonal/OLIVER_bass_one_shots/OLIVER_live_bass_one_shots/OLIVER_slaps_slides_misc/OLIVER_live_bass_one_shot_hammer_02_F#.wav
# --------------------------------------------------
#
# Name: OLIVER_live_bass_one_shot_slide_02_G#.wav
# Tempo: None
# Key: A- major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Oliver Power Tools Sample Pack/OLIVER_labeled_processed/OLIVER_tonal/OLIVER_bass_one_shots/OLIVER_live_bass_one_shots/OLIVER_slaps_slides_misc/OLIVER_live_bass_one_shot_slide_02_G#.wav
# --------------------------------------------------
#
# Name: SPINNIN_bass_synth_loop_wobble_mayhem_126_A#maj.wav
# Tempo: 126
# Key: B- major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_melodic_loops/SPINNIN_bass_synth_loop_wobble_mayhem_126_A#maj.wav
# --------------------------------------------------
#
# Name: SPINNIN_atmosphere_loop_church_126_Fmin.wav
# Tempo: 126
# Key: f minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_atmospheric_loops/SPINNIN_atmosphere_loop_church_126_Fmin.wav
# --------------------------------------------------
#
# Name: SPINNIN_synth_one_shot_intergalactic_bass_stab_Fmaj.wav
# Tempo: None
# Key: F major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_tonal/SPINNIN_synth_one_shots/SPINNIN_synth_one_shot_intergalactic_bass_stab_Fmaj.wav
# --------------------------------------------------
#
# Name: SPINNIN_top_loop_rocket_fuel_125.wav
# Tempo: 125
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_top_loops/SPINNIN_top_loop_rocket_fuel_125.wav
# --------------------------------------------------
#
# Name: SPINNIN_top_loop_apollo_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_top_loops/SPINNIN_top_loop_apollo_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_clap_one_shot_dirty.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_one_shots/SPINNIN_claps/SPINNIN_clap_one_shot_dirty.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_loop_punchy_kick_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_loops/SPINNIN_drum_loop_punchy_kick_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_fill_loop_long_builead_one_shot_128.wav
# Tempo: 128
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_fills/SPINNIN_drum_fill_loop_long_builead_one_shot_128.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_fill_loop_losing_time_126_E.wav
# Tempo: 126
# Key: E major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_fills/SPINNIN_drum_fill_loop_losing_time_126_E.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_fill_loop_falling_snare_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_fills/SPINNIN_drum_fill_loop_falling_snare_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_fill_loop_clean_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_fills/SPINNIN_drum_fill_loop_clean_126.wav
# --------------------------------------------------
#
# Name: SPINNIN_drum_fill_loop_liftoff_126_C.wav
# Tempo: 126
# Key: C major
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_drums/SPINNIN_drum_fills/SPINNIN_drum_fill_loop_liftoff_126_C.wav
# --------------------------------------------------
#
# Name: SPINNIN_impact_one_shot_epic_horns_Emaj.wav
# Tempo: None
# Key: E major
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_fx/SPINNIN_impacts/SPINNIN_impact_one_shot_epic_horns_Emaj.wav
# --------------------------------------------------
#
# Name: SPINNIN_downlifter_one_shot_short_and_clean_126.wav
# Tempo: 126
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Spinnin' Sounds Future House Sample Pack/SPINNIN_FUTURE_HOUSE_sample_pack/SPINNIN_fx/SPINNIN_downlifters/SPINNIN_downlifter_one_shot_short_and_clean_126.wav
# --------------------------------------------------
#
# Name: NICKY_ROMERO_closed_hihat_one_shot_snow.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Protocol Presents Nicky Romero Vol. 1/NICKY_ROMERO_labeled_processed/NICKY_ROMERO_drums/NICKY_ROMERO_drum_one_shots/NICKY_ROMERO_cymbals/NICKY_ROMERO_hihats/NICKY_ROMERO_closed_hihat_one_shot_snow.wav
# --------------------------------------------------
#
# ...
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Jason Evigan - The Garden Sample Pack/EVIGAN_sample_pack/EVIGAN_drums/EVIGAN_percussion_loops/EVIGAN_percussion_loop_shaker_chains_76.wav
# --------------------------------------------------
#
# Name: EVIGAN_drum_loop_80s_but_new_119.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Jason Evigan - The Garden Sample Pack/EVIGAN_sample_pack/EVIGAN_drums/EVIGAN_drum_loops/EVIGAN_full_drum_loops/EVIGAN_drum_loop_80s_but_new_119.wav
# --------------------------------------------------
#
# Name: EVIGAN_drum_loop_old_man_maggy_120.wav
# Tempo: 120
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Jason Evigan - The Garden Sample Pack/EVIGAN_sample_pack/EVIGAN_drums/EVIGAN_drum_loops/EVIGAN_full_drum_loops/EVIGAN_drum_loop_old_man_maggy_120.wav
# --------------------------------------------------
#
# Name: EVIGAN_snap_one_shot_outdoors.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Jason Evigan - The Garden Sample Pack/EVIGAN_sample_pack/EVIGAN_drums/EVIGAN_drum_one_shots/EVIGAN_snaps/EVIGAN_snap_one_shot_outdoors.wav
# --------------------------------------------------
#
# Name: EVIGAN_mouth_whistle.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Jason Evigan - The Garden Sample Pack/EVIGAN_sample_pack/EVIGAN_mouth/EVIGAN_mouth_whistle.wav
# --------------------------------------------------
#
# Name: EVIGAN_fx_sweep_one_shot_classic.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Jason Evigan - The Garden Sample Pack/EVIGAN_sample_pack/EVIGAN_fx/EVIGAN_fx_sweep/EVIGAN_fx_sweep_one_shot_classic.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_drum_loop_cannister_100.wav
# Tempo: 100
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_drums/SERJ_TANKIAN_drum_loops/SERJ_TANKIAN_drum_loop_cannister_100.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_drum_loop_heavy_100.wav
# Tempo: 100
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_drums/SERJ_TANKIAN_drum_loops/SERJ_TANKIAN_drum_loop_heavy_100.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_drum_loop_both_lasers_100.wav
# Tempo: 100
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_drums/SERJ_TANKIAN_drum_loops/SERJ_TANKIAN_drum_loop_both_lasers_100.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_orchestra_loop_violin_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_strings/SERJ_TANKIAN_orchestra_loop_violin_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_orchestra_loop_solo_violins_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_strings/SERJ_TANKIAN_orchestra_loop_solo_violins_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_orchestra_loop_cello_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_strings/SERJ_TANKIAN_orchestra_loop_cello_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_orchestra_loop_cello_mongol_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_strings/SERJ_TANKIAN_orchestra_loop_cello_mongol_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_keys_loop_hell_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_keys/SERJ_TANKIAN_keys_loop_hell_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_piano_loop_sorrowful_85_Gmin.wav
# Tempo: 85
# Key: g minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_piano/SERJ_TANKIAN_piano_loop_sorrowful_85_Gmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_piano_loop_building_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_piano/SERJ_TANKIAN_piano_loop_building_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_bass_loop_ridem_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_electric_bass/SERJ_TANKIAN_bass_loop_ridem_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_acoustic_guitar_loop_arabic_01_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_acoustic_guitar/SERJ_TANKIAN_acoustic_guitar_loop_arabic_01_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_acoustic_guitar_loop_arabic_02_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_acoustic_guitar/SERJ_TANKIAN_acoustic_guitar_loop_arabic_02_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_electric_guitar_loop_walls_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_electric_guitar/SERJ_TANKIAN_electric_guitar_loop_walls_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_electric_guitar_loop_under_water_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_electric_guitar/SERJ_TANKIAN_electric_guitar_loop_under_water_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_electric_guitar_loop_picking_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_electric_guitar/SERJ_TANKIAN_electric_guitar_loop_picking_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_electric_guitar_loop_hard_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_tonal/SERJ_TANKIAN_guitar/SERJ_TANKIAN_electric_guitar/SERJ_TANKIAN_electric_guitar_loop_hard_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_vocal_phrase_sung_aaaah_reverb_Cmin.wav
# Tempo: None
# Key: c minor
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_vocals/SERJ_TANKIAN_vocal_phrase_sung_aaaah_reverb_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_vocal_phrase_your_tears_and_fears_all_melt_away_100_Cmin.wav
# Tempo: 100
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_vocals/SERJ_TANKIAN_vocal_phrase_your_tears_and_fears_all_melt_away_100_Cmin.wav
# --------------------------------------------------
#
# Name: SERJ_TANKIAN_fx_loop_alien_teleportation_140_Cmin.wav
# Tempo: 140
# Key: c minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Serj Tankian Projectiles/SERJ_TANKIAN_sample_pack/SERJ_TANKIAN_fx/SERJ_TANKIAN_fx_loop_alien_teleportation_140_Cmin.wav
# --------------------------------------------------
#
# Name: SC_DS_120_strings_melody_hooky_legato_Gmin.wav
# Tempo: 120
# Key: g minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Audio/Loops/120_gmin/120_gmin_melodic/SC_DS_120_strings_melody_hooky_legato_Gmin.wav
# --------------------------------------------------
#
# Name: SC_DS_120_strings_stabs_swinging_upward_sting_Gmin.wav
# Tempo: 120
# Key: g minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Audio/Loops/120_gmin/120_gmin_stabsa/SC_DS_120_strings_stabs_swinging_upward_sting_Gmin.wav
# --------------------------------------------------
#
# Name: SC_DS_120_strings_stabs_glissando_hook_rising_end_Gmin.wav
# Tempo: 120
# Key: g minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Audio/Loops/120_gmin/120_gmin_stabsb/SC_DS_120_strings_stabs_glissando_hook_rising_end_Gmin.wav
# --------------------------------------------------
#
# Name: SC_DS_125_strings_riff_median_repeation_Amin.wav
# Tempo: 125
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Audio/Loops/125_amin/125_amin_melodic/SC_DS_125_strings_riff_median_repeation_Amin.wav
# --------------------------------------------------
#
# Name: SC_DS_118_strings_melody_legato_quarter_note_pickup_ending_Bmin.wav
# Tempo: 118
# Key: b minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Audio/Loops/118_bmin/118_bmin_melodic/SC_DS_118_strings_melody_legato_quarter_note_pickup_ending_Bmin.wav
# --------------------------------------------------
#
# Name: SO_DS_110_string_stack_azuki_Amin.wav
# Tempo: 110
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Loops/String_Stacks/SO_DS_110_string_stack_azuki_Amin.wav
# --------------------------------------------------
#
# Name: SO_DS_110_viola_stack_chartreuse_Dmin.wav
# Tempo: 110
# Key: d minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Disco Strings/Loops/Viola_Stacks/SO_DS_110_viola_stack_chartreuse_Dmin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_one_shot_bongo_roll_short.wav
# Tempo: None
# Key: None
# One Shot: True
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/One-Shots/Percussion_One-Shots/DIASPORA_requinto_one_shot_bongo_roll_short.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_percussion_loop_2_bachata_dry_130_bpm.wav
# Tempo: 130
# Key: None
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Percussion_Loops/02._Percussion_Loop/DIASPORA_requinto_percussion_loop_2_bachata_dry_130_bpm.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_7_full_bachata_123_bpm_Amin.wav
# Tempo: 123
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Full_/DIASPORA_requinto_melodic_loop_7_full_bachata_123_bpm_Amin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_15_full_bachata_130_Dmin.wav
# Tempo: 130
# Key: d minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Full_/DIASPORA_requinto_melodic_loop_15_full_bachata_130_Dmin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_10_full_bachata_135_bpm_Bbmin.wav
# Tempo: 135
# Key: b- minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Full_/DIASPORA_requinto_melodic_loop_10_full_bachata_135_bpm_Bbmin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_6_full_bachata_145_bpm_Emin.wav
# Tempo: 145
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Full_/DIASPORA_requinto_melodic_loop_6_full_bachata_145_bpm_Emin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_2_lead_guitar_bachata_130_bpm_Amin.wav
# Tempo: 130
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Stems_/02._Melodic_Loop/DIASPORA_requinto_melodic_loop_2_lead_guitar_bachata_130_bpm_Amin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_6_lead_guitar_bachata_145_bpm_Emin.wav
# Tempo: 145
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Stems_/06._Melodic_Loop/DIASPORA_requinto_melodic_loop_6_lead_guitar_bachata_145_bpm_Emin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_5_swing_guitar_bachata_145_bpm_Emin.wav
# Tempo: 145
# Key: e minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Stems_/05._Melodic_Loop/DIASPORA_requinto_melodic_loop_5_swing_guitar_bachata_145_bpm_Emin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_10_lead_guitar_bachata_135_bpm_Bbmin.wav
# Tempo: 135
# Key: b- minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Stems_/10._Melodic_Loop/DIASPORA_requinto_melodic_loop_10_lead_guitar_bachata_135_bpm_Bbmin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_7_lead_guitar_bachata_123_bpm_Amin.wav
# Tempo: 123
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Stems_/07._Melodic_Loop/DIASPORA_requinto_melodic_loop_7_lead_guitar_bachata_123_bpm_Amin.wav
# --------------------------------------------------
#
# Name: DIASPORA_requinto_melodic_loop_7_rhythm_guitar_bachata_123_bpm_Amin.wav
# Tempo: 123
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Requinto - Bachata/Loops/Melodic_Loops/Melodic_Loops__Stems_/07._Melodic_Loop/DIASPORA_requinto_melodic_loop_7_rhythm_guitar_bachata_123_bpm_Amin.wav
# --------------------------------------------------
#
# Name: 108_-_Am_-_Disco_Guitar_03.wav
# Tempo: 108
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Basement Freaks - 80s Disco Funk/Black_Octopus_Sound_-_80s_Disco_Funk/MUSIC_LOOPS/GUITAR/108_-_Am_-_Disco_Guitar_03.wav
# --------------------------------------------------
#
# Name: 108_-_Am_-_Disco_Guitar_04.wav
# Tempo: 108
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Basement Freaks - 80s Disco Funk/Black_Octopus_Sound_-_80s_Disco_Funk/MUSIC_LOOPS/GUITAR/108_-_Am_-_Disco_Guitar_04.wav
# --------------------------------------------------
#
# Name: 108_-_Am_-_Wah_Guitar_01.wav
# Tempo: 108
# Key: a minor
# One Shot: False
# Full path: /Users/lukemainwaring/Splice/sounds/packs/Basement Freaks - 80s Disco Funk/Black_Octopus_Sound_-_80s_Disco_Funk/MUSIC_LOOPS/GUITAR/108_-_Am_-_Wah_Guitar_01.wav
# --------------------------------------------------

# %%
# Problematic examples I could look into correcting
'''
Name: MAT_ZO_snare_094.wav
Tempo: 94
Key: None
One Shot: False
--------------------------------
***ALL SONNY_D SAMPLES SHOW UP AS D MAJOR
Name: SONNY_D_808_18_C.wav
Tempo: None
Key: D major
'''
# Out:
# '\nName: MAT_ZO_snare_094.wav\nTempo: 94\nKey: None\nOne Shot: False\n--------------------------------\n***ALL SONNY_D SAMPLES SHOW UP AS D MAJOR\nName: SONNY_D_808_18_C.wav\nTempo: None\nKey: D major\n'

# %% [markdown]
# ### Transpose samples to the relevant key
# The idea is to represent keys with the music21 library's key object. First, we get the range of keys that can be transposed without distorting the sample too much. I'm going with 2 for now, since quality sometimes sounds bad moving 3 semitones. For example, if a bass loop is already as low as it can get while still audible, we might not want to lower it 3 semitones. Maybe this range can be adjusted as part of the UX. Then, for each sample, we grab its key, and if it falls in the valid range then we transpose to the original song key.

# %%
from sample_transform import get_valid_key_range, get_candidate_sample_loops
from music21 import key

original_key = key.Key('C')
original_tempo = 120

# %%
# Creates set of keys within +/- 2 semitones
get_valid_key_range(original_key)
# Out:
# {<music21.key.Key of B- major>: -2,
#  <music21.key.Key of B major>: -1,
#  <music21.key.Key of C major>: 0,
#  <music21.key.Key of D- major>: 1,
#  <music21.key.Key of D major>: 2}

# %%
# We can also pass in a different range of steps
get_valid_key_range(original_key, 4)
# Out:
# {<music21.key.Key of A- major>: -4,
#  <music21.key.Key of A major>: -3,
#  <music21.key.Key of B- major>: -2,
#  <music21.key.Key of B major>: -1,
#  <music21.key.Key of C major>: 0,
#  <music21.key.Key of D- major>: 1,
#  <music21.key.Key of D major>: 2,
#  <music21.key.Key of E- major>: 3,
#  <music21.key.Key of E major>: 4}

# %%
# Get candidate sample loops with key in valid range and no key loops within valid bpm
# For example, this may include all samples as above plus drum loops, FX, risers, etc.
candidate_samples = get_candidate_sample_loops(sample_objects, original_tempo, original_key, require_key=False)
len(candidate_samples)
# Out:
# 232

# %%
# Get candidate sample loops with key in valid range
candidate_samples = get_candidate_sample_loops(sample_objects, original_tempo, original_key)
len(candidate_samples)
# Out:
# 14

# %% [markdown]
# ### Generate transformations on candidate samples
# This would be the step in which the candidate sample wav files get changed to match key/tempo of song

# %% [markdown]
# ## Adjust all candidate samples to match song
# If candidate samples have their bpm and key matched to the song, they can be evaluated in real time.

# %%
from sample_transform import match_sample

# %%
song_key = key.Key('C')
song_tempo = 120

for sample in candidate_samples:    
    matched_sample = match_sample(sample, song_key, song_tempo)
    sf.write('test_samples/candidate_samples_matched/' + sample.name, matched_sample, sample_rate)
    print('--------------------------------------\n')
# Out:
# Updating Tempo and Key for sample:  SPINNIN_melody_loop_intro_wubs_126_Cmaj.wav
# Transpose steps:  0
# Stretch factor:  0.9523809523809523
# --------------------------------------
#
# Updating Tempo and Key for sample:  SPINNIN_bass_synth_loop_wobble_mayhem_126_A#maj.wav
# Transpose steps:  2
# Stretch factor:  0.9523809523809523
# --------------------------------------
#
# Updating Tempo and Key for sample:  SPINNIN_drum_fill_loop_liftoff_126_C.wav
# Transpose steps:  0
# Stretch factor:  0.9523809523809523
# --------------------------------------
#
# Updating Tempo and Key for sample:  005_d__Drum_Beat_126bpm_-_AMPED_Zenhiser.wav
# Transpose steps:  -2
# Stretch factor:  0.9523809523809523
# --------------------------------------
#
# Updating Tempo and Key for sample:  015_b__Drum_Beat_126bpm_-_AMPED_Zenhiser.wav
# Transpose steps:  1
# Stretch factor:  0.9523809523809523
# --------------------------------------
#
# Updating Tempo and Key for sample:  TA_UHT_BASS_LOOP_BUNCE_126_C.wav
# Transpose steps:  0
# Stretch factor:  0.9523809523809523
# --------------------------------------
#
# Updating Tempo and Key for sample:  022__b__Drum_Loop__Without_Kick__120bpm_-_ORGANICHOUSE_Zenhiser.wav
# Transpose steps:  1
# Stretch factor:  1.0
# --------------------------------------
#
# Updating Tempo and Key for sample:  TA_MK_VOX_FEMALE12_124bpm_Db.wav
# Transpose steps:  -1
# Stretch factor:  0.967741935483871
# --------------------------------------
#
# Updating Tempo and Key for sample:  19_TA_Bass_Hit_124_D.wav
# Transpose steps:  -2
# Stretch factor:  0.967741935483871
# --------------------------------------
#
# Updating Tempo and Key for sample:  TA_Vocal_Loop_124_D.wav
# Transpose steps:  -2
# Stretch factor:  0.967741935483871
# --------------------------------------
#
# Updating Tempo and Key for sample:  08_TA_Bass_Loop_124_B_Wet.wav
# Transpose steps:  1
# Stretch factor:  0.967741935483871
# --------------------------------------
#
# Updating Tempo and Key for sample:  05_TA_Synth_Loop_124_D_Wet.wav
# Transpose steps:  -2
# Stretch factor:  0.967741935483871
# --------------------------------------
#
# Updating Tempo and Key for sample:  LSPC_Vocal_Atmosphere_10_115BPM_C.wav
# Transpose steps:  0
# Stretch factor:  1.0434782608695652
# --------------------------------------
#
# Updating Tempo and Key for sample:  STINT_vocal_choir_idea_124_C#maj.wav
# Transpose steps:  -1
# Stretch factor:  0.967741935483871
# --------------------------------------

# %% [markdown]
# ### Standardize volume
# Make sure sample is within similar volume range

# %%
# TODO: figure out if librosa, pydub, or wave is the best library for these steps
# move to sample_transform module when ready

# %% [markdown]
# ### Standardize length
# Make sure sample is looped to match the current song length

# %%
# TODO: move to sample_transform module when ready

# %%
# Basic example
guitar_sample, sample_rate = librosa.load(kshmr_guitar_file, sr=sample_rate, mono=mono)
looped_sample = np.append(guitar_sample, guitar_sample) # Looped once / doubles length

sf.write('test_samples/looped_sample.wav', looped_sample, sample_rate)

# %%
# TODO: write function that calculates how many times sample should be looped

# sample_length = len(current_sample)
# looped_sample = current_sample

# while sample_length < len(current_song):
#     looped_sample = np.append(looped_sample, current_sample)

# %% [markdown]
# ### Combine sounds into one wav file
# Now that the sample and current song are properly matched, combine and output as one file. This will be what the user hears, what gets inputted to the model, etc.

# %%
# Basic example
sample1, sample_rate = librosa.load(kshmr_guitar_file, sr=sample_rate, mono=mono)
sample2, sample_rate = librosa.load(disco_strings_file, sr=sample_rate, mono=mono)

combined_samples = sample1[:len(sample2)] + sample2 # These must be the same length
sf.write('test_samples/combined_samples.wav', combined_samples, sample_rate)
